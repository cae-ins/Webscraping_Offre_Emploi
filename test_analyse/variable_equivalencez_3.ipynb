# %%
import pandas as pd

# Charger le fichier Excel dans un DataFrame
Data_Scrapping_df_educarriere_09042024 = pd.read_excel("Data_Scrapping_df_educarriere_09042024.xlsx")

# Afficher les premières lignes du DataFrame pour vér
Data_Scrapping_df_educarriere_09042024
# Out:
#                                     BRANCHE_D_ACTIVITE  \
# 0    EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 1    EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 2    EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 3    EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 4    EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# ..                                                 ...
# 465                                 ASSISTANT RH (H/F)
# 466                                 ASSISTANT RH (H/F)
# 467                                 ASSISTANT RH (H/F)
# 468                                 ASSISTANT RH (H/F)
# 469                                 ASSISTANT RH (H/F)
#
#     TYPE_DE_CONTRAT_DU_POSTE                               SPECIALITE DIPLOME  \
# 0                     Emploi                             Informatique   BAC+5
# 1                     Emploi                             Informatique   BAC+5
# 2                     Emploi                             Informatique   BAC+5
# 3                     Emploi                             Informatique   BAC+5
# 4                     Emploi                             Informatique   BAC+5
# ..                       ...                                      ...     ...
# 465                   Emploi  Ressources Humaines , Sciences sociales   BAC+2
# 466                   Emploi  Ressources Humaines , Sciences sociales   BAC+2
# 467                   Emploi  Ressources Humaines , Sciences sociales   BAC+2
# 468                   Emploi  Ressources Humaines , Sciences sociales   BAC+2
# 469                   Emploi  Ressources Humaines , Sciences sociales   BAC+2
#
#      EXPERIENCE_PROFESSIONNELLE             LIEU_DU_POSTE_DE_TRAVAIL  \
# 0                           5.0                        Côte d'Ivoire
# 1                           5.0                        Côte d'Ivoire
# 2                           5.0                        Côte d'Ivoire
# 3                           5.0                        Côte d'Ivoire
# 4                           5.0                        Côte d'Ivoire
# ..                          ...                                  ...
# 465                         1.0  FERKESSEDOUGOU (REGION DU TCHOLOGO)
# 466                         1.0  FERKESSEDOUGOU (REGION DU TCHOLOGO)
# 467                         1.0  FERKESSEDOUGOU (REGION DU TCHOLOGO)
# 468                         1.0  FERKESSEDOUGOU (REGION DU TCHOLOGO)
# 469                         1.0  FERKESSEDOUGOU (REGION DU TCHOLOGO)
#
#                               SITE_WEB_DE_L_ENTREPRISE  \
# 0    https://emploi.educarriere.ci/offre-116075-exp...
# 1    https://emploi.educarriere.ci/offre-116075-exp...
# 2    https://emploi.educarriere.ci/offre-116075-exp...
# 3    https://emploi.educarriere.ci/offre-116075-exp...
# 4    https://emploi.educarriere.ci/offre-116075-exp...
# ..                                                 ...
# 465  https://emploi.educarriere.ci/offre-116055-ass...
# 466  https://emploi.educarriere.ci/offre-116055-ass...
# 467  https://emploi.educarriere.ci/offre-116055-ass...
# 468  https://emploi.educarriere.ci/offre-116055-ass...
# 469  https://emploi.educarriere.ci/offre-116055-ass...
#
#     DATE_DE_DEBUT_DE_L_OFFRE DATE_D_EXPIRATION_DE_L_OFFRE  \
# 0                 08/04/2024                   30/04/2024
# 1                 08/04/2024                   30/04/2024
# 2                 08/04/2024                   30/04/2024
# 3                 08/04/2024                   30/04/2024
# 4                 08/04/2024                   30/04/2024
# ..                       ...                          ...
# 465               08/04/2024                   15/04/2024
# 466               08/04/2024                   15/04/2024
# 467               08/04/2024                   15/04/2024
# 468               08/04/2024                   15/04/2024
# 469               08/04/2024                   15/04/2024
#
#                                            Description  \
# 0    MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
# 1    MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
# 2    MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
# 3    MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
# 4    MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
# ..                                                 ...
# 465  Description du posteLA MISSION D'ACTION CONTRE...
# 466  Description du posteLA MISSION D'ACTION CONTRE...
# 467  Description du posteLA MISSION D'ACTION CONTRE...
# 468  Description du posteLA MISSION D'ACTION CONTRE...
# 469  Description du posteLA MISSION D'ACTION CONTRE...
#
#                                      INTITULE_DU_POSTE  \
# 0    EXPERT DEVELOPPEMENT LOCAL - PLANIFICATION DU ...
# 1                                SUPERVISEUR RÉGIONNAL
# 2                               10 COMMERCIAUX (STAGE)
# 3                                   CONSULTANTS EN AGR
# 4                            NAVIGATIONAL WATCH RATING
# ..                                                 ...
# 465                           CHARGE COMMUNICATION H/F
# 466                    RESPONSABLE RESSOURCES HUMANIES
# 467                     FORMATEUR ELECTRICITE BATIMENT
# 468    FORMATEUR EN COLLECTE ET TRAITEMENT DES DECHETS
# 469                                  COMMUNITY MANAGER
#
#                                             Sous_titre    Code Date_DEdition  \
# 0    exXicaa-tbrecruteEXPERT DEVELOPPEMENT LOCAL - ...  111900    08/04/2024
# 1    AMIFACIrecruteSUPERVISEUR RÉGIONNALDescription...  111864    05/04/2024
# 2    BORN COTE D'IVOIRErecrute10 COMMERCIAUX (STAGE...  111844    05/04/2024
# 3    ONG EICFrecruteDES CONSULTANTS EN AGRDescripti...  111829    04/04/2024
# 4    SERVIZI ENERGIA ITALIA (SEI)recruitNAVIGATIONA...  111814    04/04/2024
# ..                                                 ...     ...           ...
# 465  IVOIRE FACILITY MANAGEMENTrecruteCHARGE COMMUN...  110615    01/03/2024
# 466  ACTUMEDIArecruteRESPONSABLE RESSOURCES HUMANIE...  110074    16/02/2024
# 467  INSTITUT PANAFRICAIN DES HAUTES ETUDES ET FORM...  108816    17/01/2024
# 468  INSTITUT PANAFRICAIN DES HAUTES ETUDES ET FORM...  107756    18/12/2023
# 469  Description du postea l'aide de votre smartpho...  105957    06/11/2023
#
#     Date_limite PAYS_DU_POSTE_DE_TRAVAIL  \
# 0    15/04/2024                   d'I...
# 1    15/04/2024                   d'I...
# 2    15/04/2024                  ABIDJAN
# 3    15/04/2024                    et...
# 4    27/04/2024                     O...
# ..          ...                      ...
# 465  31/12/2024                 d'Ivoire
# 466  13/08/2024                 D'IVOIRE
# 467  29/08/2024                   d'I...
# 468  01/08/2024                  Abidjan
# 469  23/04/2024                 yopougon
#
#                                                    URL  \
# 0    https://emploi.educarriere.ci/nos-offres?page1...
# 1    https://emploi.educarriere.ci/nos-offres?page1...
# 2    https://emploi.educarriere.ci/nos-offres?page1...
# 3    https://emploi.educarriere.ci/nos-offres?page1...
# 4    https://emploi.educarriere.ci/nos-offres?page1...
# ..                                                 ...
# 465  https://emploi.educarriere.ci/nos-offres?page1...
# 466  https://emploi.educarriere.ci/nos-offres?page1...
# 467  https://emploi.educarriere.ci/nos-offres?page1...
# 468  https://emploi.educarriere.ci/nos-offres?page1...
# 469  https://emploi.educarriere.ci/nos-offres?page1...
#
#     Unite_EXPERIENCE_PROFESSIONNELLE
# 0                                ans
# 1                                ans
# 2                                ans
# 3                                ans
# 4                                ans
# ..                               ...
# 465                              ans
# 466                              ans
# 467                              ans
# 468                              ans
# 469                              ans
#
# [470 rows x 18 columns]

# %%
Data_Scrapping_df_novojob_09042024 = pd.read_excel("Data_Scrapping_df_novojob_09042024.xlsx")

# Afficher les premières lignes du DataFrame pour vér
Data_Scrapping_df_novojob_09042024
# Out:
#                         INTITULE_DU_POSTE                   Entreprise  \
# 0    Gestionnaire des Ressources Humaines                          NaN
# 1    Gestionnaire des Ressources Humaines                          NaN
# 2    Gestionnaire des Ressources Humaines                          NaN
# 3    Gestionnaire des Ressources Humaines                          NaN
# 4    Gestionnaire des Ressources Humaines                          NaN
# ..                                    ...                          ...
# 769                   Maintenance Officer  OLAM FOOD Ingrédients (OFI)
# 770                   Maintenance Officer  OLAM FOOD Ingrédients (OFI)
# 771                   Maintenance Officer  OLAM FOOD Ingrédients (OFI)
# 772                  Production in Charge  OLAM FOOD Ingrédients (OFI)
# 773                  Conducteur Chaudière  OLAM FOOD Ingrédients (OFI)
#
#     PAYS_DU_POSTE_DE_TRAVAIL DATE_DE_DEBUT_DE_L_OFFRE  \
# 0              Côte d'ivoire                  24 Mars
# 1              Côte d'ivoire                  24 Mars
# 2              Côte d'ivoire                  24 Mars
# 3              Côte d'ivoire                  24 Mars
# 4              Côte d'ivoire                  24 Mars
# ..                       ...                      ...
# 769            Côte d'ivoire               31 Janvier
# 770            Côte d'ivoire               31 Janvier
# 771            Côte d'ivoire               31 Janvier
# 772            Côte d'ivoire               06 Février
# 773            Côte d'ivoire               31 Janvier
#
#                                 Niveau Experience_lettre  \
# 0    Manager / Responsable département        6 à 10 ans
# 1    Manager / Responsable département        6 à 10 ans
# 2    Manager / Responsable département        6 à 10 ans
# 3    Manager / Responsable département        6 à 10 ans
# 4    Manager / Responsable département        6 à 10 ans
# ..                                 ...               ...
# 769             Confirmé / Expérimenté        6 à 10 ans
# 770             Confirmé / Expérimenté        6 à 10 ans
# 771             Confirmé / Expérimenté        6 à 10 ans
# 772             Confirmé / Expérimenté        6 à 10 ans
# 773                  Débutant / Junior         3 à 5 ans
#
#                                                    url  \
# 0    https://www.novojob.com/cote-d-ivoire/offres-d...
# 1    https://www.novojob.com/cote-d-ivoire/offres-d...
# 2    https://www.novojob.com/cote-d-ivoire/offres-d...
# 3    https://www.novojob.com/cote-d-ivoire/offres-d...
# 4    https://www.novojob.com/cote-d-ivoire/offres-d...
# ..                                                 ...
# 769  https://www.novojob.com/cote-d-ivoire/offres-d...
# 770  https://www.novojob.com/cote-d-ivoire/offres-d...
# 771  https://www.novojob.com/cote-d-ivoire/offres-d...
# 772  https://www.novojob.com/cote-d-ivoire/offres-d...
# 773  https://www.novojob.com/cote-d-ivoire/offres-d...
#
#                               SITE_WEB_DE_L_ENTREPRISE  \
# 0    https://www.novojob.com/cote-d-ivoire/offres-d...
# 1    https://www.novojob.com/cote-d-ivoire/offres-d...
# 2    https://www.novojob.com/cote-d-ivoire/offres-d...
# 3    https://www.novojob.com/cote-d-ivoire/offres-d...
# 4    https://www.novojob.com/cote-d-ivoire/offres-d...
# ..                                                 ...
# 769  https://www.novojob.com/cote-d-ivoire/offres-d...
# 770  https://www.novojob.com/cote-d-ivoire/offres-d...
# 771  https://www.novojob.com/cote-d-ivoire/offres-d...
# 772  https://www.novojob.com/cote-d-ivoire/offres-d...
# 773  https://www.novojob.com/cote-d-ivoire/offres-d...
#
#     LIEU_DU_POSTE_DE_TRAVAIL DATE_D_EXPIRATION_DE_L_OFFRE  \
# 0     Abidjan, Côte d'ivoire                      22 Juin
# 1     Abidjan, Côte d'ivoire                      22 Juin
# 2     Abidjan, Côte d'ivoire                      22 Juin
# 3     Abidjan, Côte d'ivoire                      22 Juin
# 4     Abidjan, Côte d'ivoire                      22 Juin
# ..                       ...                          ...
# 769    Bouake, Côte d'ivoire                     30 Avril
# 770    Bouake, Côte d'ivoire                     30 Avril
# 771    Bouake, Côte d'ivoire                     30 Avril
# 772    Bouake, Côte d'ivoire                       06 Mai
# 773   Abidjan, Côte d'ivoire                     30 Avril
#
#                        Niveau de poste      BRANCHE_D_ACTIVITE  \
# 0    Manager / Responsable département                Services
# 1    Manager / Responsable département                Services
# 2    Manager / Responsable département                Services
# 3    Manager / Responsable département                Services
# 4    Manager / Responsable département                Services
# ..                                 ...                     ...
# 769             Confirmé / Expérimenté  Distribution, Commerce
# 770             Confirmé / Expérimenté  Distribution, Commerce
# 771             Confirmé / Expérimenté  Distribution, Commerce
# 772             Confirmé / Expérimenté  Distribution, Commerce
# 773                  Débutant / Junior  Distribution, Commerce
#
#                                           Texte_fourni  \
# 0    Entreprise spécialisée dans l’ingénierie mécan...
# 1    Entreprise spécialisée dans l’ingénierie mécan...
# 2    Entreprise spécialisée dans l’ingénierie mécan...
# 3    Entreprise spécialisée dans l’ingénierie mécan...
# 4    Entreprise spécialisée dans l’ingénierie mécan...
# ..                                                 ...
# 769  Position within the structure :Position based ...
# 770  Position within the structure :Position based ...
# 771  Position within the structure :Position based ...
# 772  Présentation de l’entreprise \nOLAM FOOD ingre...
# 773  Position dans la structure: Poste basé à San P...
#
#        Niveau d'étude (diplome)  NOMBRE_DE_POSTES_A_POURVOIR  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# ..                          ...                          ...
# 769   Formation Professionnelle                          1.0
# 770   Formation Professionnelle                          1.0
# 771   Formation Professionnelle                          1.0
# 772  Master 1, Licence  Bac + 4                          1.0
# 773   Formation Professionnelle                          1.0
#
#     TYPE_DE_CONTRAT_DU_POSTE RAISON_SOCIALE_DE_L_ENTREPRISE  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
# ..                       ...                            ...
# 769                      CDI                            NaN
# 770                      CDI                            NaN
# 771                      CDI                            NaN
# 772                      CDI                            NaN
# 773                      CDI                            NaN
#
#     VILLE_DU_POSTE_DE_TRAVAIL
# 0                     Abidjan
# 1                     Abidjan
# 2                     Abidjan
# 3                     Abidjan
# 4                     Abidjan
# ..                        ...
# 769                    Bouake
# 770                    Bouake
# 771                    Bouake
# 772                    Bouake
# 773                   Abidjan
#
# [774 rows x 18 columns]

# %%
Data_Scrapping_df_projobivoire_09042024 = pd.read_excel("Data_Scrapping_df_projobivoire_09042024.xlsx")

# Afficher les premières lignes du DataFrame pour vér
Data_Scrapping_df_projobivoire_09042024
# Out:
#                                       INTITULE_DU_POSTE  \
# 0     Solidaridad West Africa recrute Conseiller(e) ...
# 1     Société Générale Côte D’ivoire recrute Attaché...
# 2                      Agent WAVE dans plusieurs Villes
# 3        IVAN’S GROUP recrute Responsable de Trésorerie
# 4     Stagiaire Assistant Communication et Marketing...
# ...                                                 ...
# 9277  PSI CI recrute 02 CONSEILLERS TECHNIQUES RÉGIO...
# 9278   La Banque Atlantique recrute de nouveaux profils
# 9279    Les Orchidées Rouges recrutent Chargé de projet
# 9280                               DIRECTEUR DES ETUDES
# 9281      STAGIAIRE COMPTABLE ET GESTIONNAIRE DE STOCKS
#
#      TYPE_DE_CONTRAT_DU_POSTE DATE_DE_PUBLICATION  \
# 0                      Emploi        8 avril 2024
# 1                      Emploi        8 avril 2024
# 2                     Contrat        8 avril 2024
# 3                      Emploi        8 avril 2024
# 4                       Stage        8 avril 2024
# ...                       ...                 ...
# 9277                   Emploi   20 septembre 2021
# 9278                   Emploi   20 septembre 2021
# 9279                   Emploi   20 septembre 2021
# 9280                   Emploi   20 septembre 2021
# 9281                    Stage   20 septembre 2021
#
#      DATE_D_EXPIRATION_DE_L_OFFRE               CATEGORIE  \
# 0                   23 avril 2024                     NaN
# 1                   23 avril 2024                  Banque
# 2                   23 avril 2024         Commerce/Ventes
# 3                   23 avril 2024   Finances/Comptabilité
# 4                   23 avril 2024           Communication
# ...                           ...                     ...
# 9277            24 septembre 2021          Médecine/Santé
# 9278            24 septembre 2021                  Banque
# 9279            24 septembre 2021                     NaN
# 9280            24 septembre 2021  Education/Enseignement
# 9281            24 septembre 2021   Finances/Comptabilité
#
#                                                EmailURL  \
# 0     https://projobivoire.com/jobs/solidaridad-west...
# 1     https://projobivoire.com/jobs/societe-generale...
# 2     https://projobivoire.com/jobs/agent-wave-dans-...
# 3     https://projobivoire.com/jobs/ivans-group-recr...
# 4     https://projobivoire.com/jobs/stagiaire-assist...
# ...                                                 ...
# 9277  https://projobivoire.com/jobs/psi-ci-recrute-0...
# 9278  https://projobivoire.com/jobs/la-banque-atlant...
# 9279  https://projobivoire.com/jobs/les-orchidees-ro...
# 9280  https://projobivoire.com/jobs/directeur-des-et...
# 9281  https://projobivoire.com/jobs/stagiaire-compta...
#
#                 SITE_WEB_DE_L_ENTREPRISE
# 0       https://projobivoire.com/page/0/
# 1       https://projobivoire.com/page/0/
# 2       https://projobivoire.com/page/0/
# 3       https://projobivoire.com/page/0/
# 4       https://projobivoire.com/page/0/
# ...                                  ...
# 9277  https://projobivoire.com/page/545/
# 9278  https://projobivoire.com/page/545/
# 9279  https://projobivoire.com/page/545/
# 9280  https://projobivoire.com/page/545/
# 9281  https://projobivoire.com/page/545/
#
# [9282 rows x 7 columns]

# %%
Data_Scrapping_df_talent_ci_09042024 = pd.read_excel("Data_Scrapping_df_talent_ci_09042024.xlsx")

# Afficher les premières lignes du DataFrame pour vér
Data_Scrapping_df_talent_ci_09042024
# Out:
#                                      INTITULE_DU_POSTE  \
# 0    Country Technical Sales Manager – West Africa ...
# 1                                       Chauffeur Moto
# 2                         Chef comptable assurance vie
# 3                   Assistante RH / Assistant RH (H/F)
# 4                        Agent de sécurite gardiennage
# ..                                                 ...
# 151                 Mécanicien / Mécanicienne agricole
# 152                                Credit Risk Officer
# 153                  Senior Consultant, Client Success
# 154                        Technicien chauffagiste H/F
# 155                Ivory Coast Cluster Revenue Manager
#
#                  LIEU_DU_POSTE_DE_TRAVAIL     RAISON_SOCIALE_DE_L_ENTREPRISE  \
# 0                        Abidjan, Abidjan                      Claire Joster
# 1                        Abidjan, Abidjan                        Deals Jumia
# 2                        Abidjan, Abidjan                             Senjob
# 3                        Abidjan, Abidjan                                RMO
# 4                        Abidjan, Abidjan                     ESMA (ABIDJAN)
# ..                                    ...                                ...
# 151                      Abidjan, Lagunes                           Temporis
# 152                      Abidjan, Lagunes  09220 Citibank Cote d'Ivoire S.A.
# 153               Abidjan, Lagunes Region                               VISA
# 154  Abidjan, Abidjan Autonomous District                             Acorus
# 155  Abidjan, Abidjan Autonomous District                              ACCOR
#
#                                   DESCRIPTION_DU_POSTE  \
# 0    PresentaciónClaire Joster is a headhunting fir...
# 1    Description. NE PAYEZ AUCUN FRAIS DE DOSSIERS ...
# 2    Au sein de la Direction Administrative et Fina...
# 3    Le PosteRecruteurImplanté en Afrique, RMO vous...
# 4    Description de l'emploiEn quoi consiste l'empl...
# ..                                                 ...
# 151  TEMPORIS Vendée Littoral, plus que des agences...
# 152  The Country Risk Senior Analyst is a seasoned ...
# 153  Job Description And ResponsibilitiesThis is an...
# 154  LE POSTE..️ Qui dit croissance, dit création d...
# 155  Job DescriptionProperties Abidjan Accor Hotels...
#
#                               SITE_WEB_DE_L_ENTREPRISE
# 0    https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
# 1    https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
# 2    https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
# 3    https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
# 4    https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
# ..                                                 ...
# 151  https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
# 152  https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
# 153  https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
# 154  https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
# 155  https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
#
# [156 rows x 5 columns]

# %%
Data_Scrapping_emploi_df_09042024 = pd.read_excel("Data_Scrapping_emploi_df_09042024.xlsx")

# Afficher les premières lignes du DataFrame pour vér
Data_Scrapping_emploi_df_09042024
# Out:
#                            Poste  Entreprise        Date  \
# 0     Technicien Support OPS H/F     INSTAHR  07.04.2024
# 1     Technicien Support OPS H/F     INSTAHR  07.04.2024
# 2     Technicien Support OPS H/F     INSTAHR  07.04.2024
# 3     Technicien Support OPS H/F     INSTAHR  07.04.2024
# 4     Technicien Support OPS H/F     INSTAHR  07.04.2024
# ...                          ...         ...         ...
# 2461         Directeur Technique  AFRICAWORK  23.02.2024
# 2462         Directeur Technique  AFRICAWORK  23.02.2024
# 2463         Directeur Technique  AFRICAWORK  23.02.2024
# 2464         Directeur Technique  AFRICAWORK  23.02.2024
# 2465         Directeur Technique  AFRICAWORK  23.02.2024
#
#                                             Description  Région  \
# 0     Instahr, une entreprise canadienne, recrute po...     NaN
# 1     Instahr, une entreprise canadienne, recrute po...     NaN
# 2     Instahr, une entreprise canadienne, recrute po...     NaN
# 3     Instahr, une entreprise canadienne, recrute po...     NaN
# 4     Instahr, une entreprise canadienne, recrute po...     NaN
# ...                                                 ...     ...
# 2461  MISSION PRINCIPALEAssurer le suivi des interve...     NaN
# 2462  MISSION PRINCIPALEAssurer le suivi des interve...     NaN
# 2463  MISSION PRINCIPALEAssurer le suivi des interve...     NaN
# 2464  MISSION PRINCIPALEAssurer le suivi des interve...     NaN
# 2465  MISSION PRINCIPALEAssurer le suivi des interve...     NaN
#
#                                                     URL  \
# 0     https://www.emploi.ci/recherche-jobs-cote-ivoi...
# 1     https://www.emploi.ci/recherche-jobs-cote-ivoi...
# 2     https://www.emploi.ci/recherche-jobs-cote-ivoi...
# 3     https://www.emploi.ci/recherche-jobs-cote-ivoi...
# 4     https://www.emploi.ci/recherche-jobs-cote-ivoi...
# ...                                                 ...
# 2461  https://www.emploi.ci/recherche-jobs-cote-ivoi...
# 2462  https://www.emploi.ci/recherche-jobs-cote-ivoi...
# 2463  https://www.emploi.ci/recherche-jobs-cote-ivoi...
# 2464  https://www.emploi.ci/recherche-jobs-cote-ivoi...
# 2465  https://www.emploi.ci/recherche-jobs-cote-ivoi...
#
#                                              Offre_Link
# 0     https://www.emploi.ci/offre-emploi-cote-ivoire...
# 1     https://www.emploi.ci/offre-emploi-cote-ivoire...
# 2     https://www.emploi.ci/offre-emploi-cote-ivoire...
# 3     https://www.emploi.ci/offre-emploi-cote-ivoire...
# 4     https://www.emploi.ci/offre-emploi-cote-ivoire...
# ...                                                 ...
# 2461  https://www.emploi.ci/offre-emploi-cote-ivoire...
# 2462  https://www.emploi.ci/offre-emploi-cote-ivoire...
# 2463  https://www.emploi.ci/offre-emploi-cote-ivoire...
# 2464  https://www.emploi.ci/offre-emploi-cote-ivoire...
# 2465  https://www.emploi.ci/offre-emploi-cote-ivoire...
#
# [2466 rows x 7 columns]

# %%
Data_Scrapping_mondiale_df_09042024 = pd.read_excel("Data_Scrapping_mondiale_df_09042024.xlsx")

# Afficher les premières lignes du DataFrame pour vér 
Data_Scrapping_mondiale_df_09042024
# Out:
#                                     INTITULE_DU_POSTE  \
# 0   (Senior) Industry Specialist – Tourism (Hospit...
# 1   Associate Environmental and Social Development...
# 2   Associate Environmental and Social Development...
# 3                        Associate Investment Officer
# 4                        Associate Investment Officer
# 5                        Associate Investment Officer
# 6     Associate Investment Officer/Investment Officer
# 7     Associate Operations Officer/Operations Officer
# 8                                    Business Analyst
# 9                              Climate Change Analyst
# 10  Climate Change Analyst (Programming and Innova...
# 11        Corporate Procurement Category Analyst HRPS
# 12        Corporate Procurement Category Manager HRPS
# 13                                            Counsel
# 14                                            Counsel
# 15                                    Country Officer
# 16                                             Driver
# 17                                             Driver
# 18                                     E T Consultant
# 19                                     E T Consultant
# 20  (Senior) Industry Specialist – Tourism (Hospit...
# 21  Associate Environmental and Social Development...
# 22  Associate Environmental and Social Development...
# 23                       Associate Investment Officer
# 24                       Associate Investment Officer
# 25                       Associate Investment Officer
# 26    Associate Investment Officer/Investment Officer
# 27    Associate Operations Officer/Operations Officer
# 28                                   Business Analyst
# 29                             Climate Change Analyst
# 30  Climate Change Analyst (Programming and Innova...
# 31        Corporate Procurement Category Analyst HRPS
# 32        Corporate Procurement Category Manager HRPS
# 33                                            Counsel
# 34                                            Counsel
# 35                                    Country Officer
# 36                                             Driver
# 37                                             Driver
# 38                                     E T Consultant
# 39                                     E T Consultant
# 40  (Senior) Industry Specialist – Tourism (Hospit...
# 41  Associate Environmental and Social Development...
# 42  Associate Environmental and Social Development...
# 43                       Associate Investment Officer
# 44                       Associate Investment Officer
# 45                       Associate Investment Officer
# 46    Associate Investment Officer/Investment Officer
# 47    Associate Operations Officer/Operations Officer
# 48                                   Business Analyst
# 49                             Climate Change Analyst
# 50  Climate Change Analyst (Programming and Innova...
# 51        Corporate Procurement Category Analyst HRPS
# 52        Corporate Procurement Category Manager HRPS
# 53                                            Counsel
# 54                                            Counsel
# 55                                    Country Officer
# 56                                             Driver
# 57                                             Driver
# 58                                     E T Consultant
# 59                                     E T Consultant
#
#         LIEU_DU_POSTE_DE_TRAVAIL                        SECTEUR  \
# 0   Washington, DC,United States                     Investment
# 1                 Hanoi,Viet Nam                    Environment
# 2                   Mumbai,India                    Environment
# 3                Belgrade,Serbia                     Investment
# 4       Mexico City,Mexico  More                     Investment
# 5               Istanbul,Turkiye                     Investment
# 6              Cairo,Egypt  More                     Investment
# 7                  Nairobi,Kenya                         Gender
# 8                  Chennai,India         Information Technology
# 9   Washington, DC,United States                 Climate Change
# 10  Washington, DC,United States                 Climate Change
# 11                Sofia,Bulgaria                    Procurement
# 12  Washington, DC,United States                    Procurement
# 13                 Dakar,Senegal                          Legal
# 14  Washington, DC,United States                          Legal
# 15         Freetown,Sierra Leone                          Other
# 16                  Kyiv,Ukraine  Administration/Office Support
# 17            Panama City,Panama  Administration/Office Support
# 18              Brussels,Belgium                 Transportation
# 19  Washington, DC,United States    Health/Nutrition/Population
# 20  Washington, DC,United States                     Investment
# 21                Hanoi,Viet Nam                    Environment
# 22                  Mumbai,India                    Environment
# 23               Belgrade,Serbia                     Investment
# 24      Mexico City,Mexico  More                     Investment
# 25              Istanbul,Turkiye                     Investment
# 26             Cairo,Egypt  More                     Investment
# 27                 Nairobi,Kenya                         Gender
# 28                 Chennai,India         Information Technology
# 29  Washington, DC,United States                 Climate Change
# 30  Washington, DC,United States                 Climate Change
# 31                Sofia,Bulgaria                    Procurement
# 32  Washington, DC,United States                    Procurement
# 33                 Dakar,Senegal                          Legal
# 34  Washington, DC,United States                          Legal
# 35         Freetown,Sierra Leone                          Other
# 36                  Kyiv,Ukraine  Administration/Office Support
# 37            Panama City,Panama  Administration/Office Support
# 38              Brussels,Belgium                 Transportation
# 39  Washington, DC,United States    Health/Nutrition/Population
# 40  Washington, DC,United States                     Investment
# 41                Hanoi,Viet Nam                    Environment
# 42                  Mumbai,India                    Environment
# 43               Belgrade,Serbia                     Investment
# 44      Mexico City,Mexico  More                     Investment
# 45              Istanbul,Turkiye                     Investment
# 46             Cairo,Egypt  More                     Investment
# 47                 Nairobi,Kenya                         Gender
# 48                 Chennai,India         Information Technology
# 49  Washington, DC,United States                 Climate Change
# 50  Washington, DC,United States                 Climate Change
# 51                Sofia,Bulgaria                    Procurement
# 52  Washington, DC,United States                    Procurement
# 53                 Dakar,Senegal                          Legal
# 54  Washington, DC,United States                          Legal
# 55         Freetown,Sierra Leone                          Other
# 56                  Kyiv,Ukraine  Administration/Office Support
# 57            Panama City,Panama  Administration/Office Support
# 58              Brussels,Belgium                 Transportation
# 59  Washington, DC,United States    Health/Nutrition/Population
#
#    DATE_D_EXPIRATION_DE_L_OFFRE
# 0                     4/25/2024
# 1                     4/18/2024
# 2                     4/20/2024
# 3                     4/10/2024
# 4                     4/15/2024
# 5                     4/17/2024
# 6                     4/16/2024
# 7                     4/20/2024
# 8                     4/28/2024
# 9                     4/10/2024
# 10                    4/10/2024
# 11                    4/19/2024
# 12                    4/19/2024
# 13                    4/15/2024
# 14                    4/19/2024
# 15                    4/17/2024
# 16                    4/15/2024
# 17                    4/17/2024
# 18                     4/9/2024
# 19                    4/15/2024
# 20                    4/25/2024
# 21                    4/18/2024
# 22                    4/20/2024
# 23                    4/10/2024
# 24                    4/15/2024
# 25                    4/17/2024
# 26                    4/16/2024
# 27                    4/20/2024
# 28                    4/28/2024
# 29                    4/10/2024
# 30                    4/10/2024
# 31                    4/19/2024
# 32                    4/19/2024
# 33                    4/15/2024
# 34                    4/19/2024
# 35                    4/17/2024
# 36                    4/15/2024
# 37                    4/17/2024
# 38                     4/9/2024
# 39                    4/15/2024
# 40                    4/25/2024
# 41                    4/18/2024
# 42                    4/20/2024
# 43                    4/10/2024
# 44                    4/15/2024
# 45                    4/17/2024
# 46                    4/16/2024
# 47                    4/20/2024
# 48                    4/28/2024
# 49                    4/10/2024
# 50                    4/10/2024
# 51                    4/19/2024
# 52                    4/19/2024
# 53                    4/15/2024
# 54                    4/19/2024
# 55                    4/17/2024
# 56                    4/15/2024
# 57                    4/17/2024
# 58                     4/9/2024
# 59                    4/15/2024

# %%
Data_Scrapping_yop_l_frii_total_09042024 = pd.read_excel("Data_Scrapping_yop_l_frii_total_09042024.xlsx")

# Afficher les premières lignes du DataFrame pour vér 
Data_Scrapping_yop_l_frii_total_09042024
# Out:
#                                        INTITULE_DU_POSTE  \
# 0                      Le PAM recrute pour ces 2 postes
# 1                      Le PAM recrute pour ces 2 postes
# 2      L’Organisation internationale URC recrute pour...
# 3            L’UNION AFRICAINE UA recrute pour ce poste
# 4      Le Centre du riz pour l’Afrique AfricaRice rec...
# ...                                                  ...
# 39309                       ACTED recrute pour ce poste
# 39310  Médecins Sans Frontières MSF recrute pour ce p...
# 39311                      FHI360 recrute pour ce poste
# 39312           L’ONG Le GRET recrute pour ces 3 postes
# 39313                 Le PNUD recrute pour ces 2 postes
#
#                                             URL_DU_POSTE  \
# 0      https://yop.l-frii.com/emploi/le-pam-recrute-p...
# 1      https://yop.l-frii.com/emploi/le-pam-recrute-p...
# 2      https://yop.l-frii.com/emploi/lorganisation-in...
# 3      https://yop.l-frii.com/emploi/lunion-africaine...
# 4      https://yop.l-frii.com/emploi/le-centre-du-riz...
# ...                                                  ...
# 39309  https://yop.l-frii.com/emploi/acted-recrute-po...
# 39310  https://yop.l-frii.com/emploi/medecins-sans-fr...
# 39311  https://yop.l-frii.com/emploi/fhi360-recrute-p...
# 39312  https://yop.l-frii.com/emploi/long-le-gret-rec...
# 39313  https://yop.l-frii.com/emploi/le-pnud-recrute-...
#
#                                                Job Image  \
# 0      https://yop.l-frii.com/wp-content/uploads/2024...
# 1      https://yop.l-frii.com/wp-content/uploads/2024...
# 2      https://yop.l-frii.com/wp-content/uploads/2024...
# 3      https://yop.l-frii.com/wp-content/uploads/2024...
# 4      https://yop.l-frii.com/wp-content/uploads/2024...
# ...                                                  ...
# 39309  https://yop.l-frii.com/wp-content/uploads/2022...
# 39310  https://yop.l-frii.com/wp-content/uploads/2022...
# 39311  https://yop.l-frii.com/wp-content/uploads/2022...
# 39312  https://yop.l-frii.com/wp-content/uploads/2021...
# 39313  https://yop.l-frii.com/wp-content/uploads/2022...
#
#                                          Source URL DATE_DE_DEBUT_DE_L_OFFRE  \
# 0         https://yop.l-frii.com/offres-demplois/0/            08 Avril 2024
# 1         https://yop.l-frii.com/offres-demplois/1/            08 Avril 2024
# 2         https://yop.l-frii.com/offres-demplois/0/            08 Avril 2024
# 3         https://yop.l-frii.com/offres-demplois/0/            08 Avril 2024
# 4         https://yop.l-frii.com/offres-demplois/0/            08 Avril 2024
# ...                                             ...                      ...
# 39309  https://yop.l-frii.com/offres-demplois/3275/          16 Janvier 2022
# 39310  https://yop.l-frii.com/offres-demplois/3275/          17 Janvier 2022
# 39311  https://yop.l-frii.com/offres-demplois/3275/          17 Janvier 2022
# 39312  https://yop.l-frii.com/offres-demplois/3275/          17 Janvier 2022
# 39313  https://yop.l-frii.com/offres-demplois/3275/          17 Janvier 2022
#
#        NOMBRE_DE_POSTE_DE_TRAVAIL       Titre du Poste  \
# 0                             2.0  2023 © L-FRII MEDIA
# 1                             2.0  2023 © L-FRII MEDIA
# 2                             2.0  2023 © L-FRII MEDIA
# 3                             NaN  2023 © L-FRII MEDIA
# 4                            10.0  2023 © L-FRII MEDIA
# ...                           ...                  ...
# 39309                         NaN  2023 © L-FRII MEDIA
# 39310                         NaN  2023 © L-FRII MEDIA
# 39311                         NaN  2023 © L-FRII MEDIA
# 39312                         3.0  2023 © L-FRII MEDIA
# 39313                         2.0  2023 © L-FRII MEDIA
#
#                          Niveau Requis Année d'Expérience Requise  \
# 0      Diplôme universitaire supérieur               2 ans, 6 ans
# 1      Diplôme universitaire supérieur               2 ans, 6 ans
# 2                                  NaN                        NaN
# 3                               Master                        NaN
# 4                                  NaN                        NaN
# ...                                ...                        ...
# 39309                  Licence, Master                      5 ans
# 39310                         Doctorat                      2 ans
# 39311                          BAC + 3                      5 ans
# 39312  Diplôme universitaire supérieur                      3 ans
# 39313                              NaN                        NaN
#
#                       Lieu du Travail Date de Soumission annee_min annee_max  \
# 0                      Guinée / Bénin         21/04/2024         2         6
# 1                      Guinée / Bénin         21/04/2024         2         6
# 2                     Abuja , Nigéria                NaN       NaN       NaN
# 3                             Algérie         08/05/2024       NaN       NaN
# 4      Côte d'Ivoire / Sénégal / Togo                NaN       NaN       NaN
# ...                               ...                ...       ...       ...
# 39309                             NaN                NaN         5         5
# 39310       Burkina-Faso, Mali, Niger         07/02/2022         2         2
# 39311                 Cotonou - Bénin         07/02/2022         5         5
# 39312                          Guinée         30/01/2022         3         3
# 39313                             NaN         31/01/2022       NaN       NaN
#
#              LIEU_DU_POSTE_DE_TRAVAIL        PAYS_DU_POSTE_DE_TRAVAIL
# 0                      Guinée / Bénin                  Guinée / Bénin
# 1                      Guinée / Bénin                  Guinée / Bénin
# 2                              Abuja                          Nigéria
# 3                             Algérie                         Algérie
# 4      Côte d'Ivoire / Sénégal / Togo  Côte d'Ivoire / Sénégal / Togo
# ...                               ...                             ...
# 39309                             NaN                             NaN
# 39310                    Burkina-Faso                     Mali, Niger
# 39311                 Cotonou - Bénin                 Cotonou - Bénin
# 39312                          Guinée                          Guinée
# 39313                             NaN                             NaN
#
# [39314 rows x 15 columns]

# %%
# Concaténer les DataFrames
frames = [Data_Scrapping_df_educarriere_09042024, 
          Data_Scrapping_df_novojob_09042024, 
          Data_Scrapping_df_projobivoire_09042024, 
          Data_Scrapping_df_talent_ci_09042024, 
          Data_Scrapping_emploi_df_09042024, 
          Data_Scrapping_mondiale_df_09042024, 
          Data_Scrapping_yop_l_frii_total_09042024]
frames
# Out:
# [                                    BRANCHE_D_ACTIVITE  \
#  0    EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
#  1    EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
#  2    EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
#  3    EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
#  4    EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
#  ..                                                 ...
#  465                                 ASSISTANT RH (H/F)
#  466                                 ASSISTANT RH (H/F)
#  467                                 ASSISTANT RH (H/F)
#  468                                 ASSISTANT RH (H/F)
#  469                                 ASSISTANT RH (H/F)
#
#      TYPE_DE_CONTRAT_DU_POSTE                               SPECIALITE DIPLOME  \
#  0                     Emploi                             Informatique   BAC+5
#  1                     Emploi                             Informatique   BAC+5
#  2                     Emploi                             Informatique   BAC+5
#  3                     Emploi                             Informatique   BAC+5
#  4                     Emploi                             Informatique   BAC+5
#  ..                       ...                                      ...     ...
#  465                   Emploi  Ressources Humaines , Sciences sociales   BAC+2
#  466                   Emploi  Ressources Humaines , Sciences sociales   BAC+2
#  467                   Emploi  Ressources Humaines , Sciences sociales   BAC+2
#  468                   Emploi  Ressources Humaines , Sciences sociales   BAC+2
#  469                   Emploi  Ressources Humaines , Sciences sociales   BAC+2
#
#       EXPERIENCE_PROFESSIONNELLE             LIEU_DU_POSTE_DE_TRAVAIL  \
#  0                           5.0                        Côte d'Ivoire
#  1                           5.0                        Côte d'Ivoire
#  2                           5.0                        Côte d'Ivoire
#  3                           5.0                        Côte d'Ivoire
#  4                           5.0                        Côte d'Ivoire
#  ..                          ...                                  ...
#  465                         1.0  FERKESSEDOUGOU (REGION DU TCHOLOGO)
#  466                         1.0  FERKESSEDOUGOU (REGION DU TCHOLOGO)
#  467                         1.0  FERKESSEDOUGOU (REGION DU TCHOLOGO)
#  468                         1.0  FERKESSEDOUGOU (REGION DU TCHOLOGO)
#  469                         1.0  FERKESSEDOUGOU (REGION DU TCHOLOGO)
#
#                                SITE_WEB_DE_L_ENTREPRISE  \
#  0    https://emploi.educarriere.ci/offre-116075-exp...
#  1    https://emploi.educarriere.ci/offre-116075-exp...
#  2    https://emploi.educarriere.ci/offre-116075-exp...
#  3    https://emploi.educarriere.ci/offre-116075-exp...
#  4    https://emploi.educarriere.ci/offre-116075-exp...
#  ..                                                 ...
#  465  https://emploi.educarriere.ci/offre-116055-ass...
#  466  https://emploi.educarriere.ci/offre-116055-ass...
#  467  https://emploi.educarriere.ci/offre-116055-ass...
#  468  https://emploi.educarriere.ci/offre-116055-ass...
#  469  https://emploi.educarriere.ci/offre-116055-ass...
#
#      DATE_DE_DEBUT_DE_L_OFFRE DATE_D_EXPIRATION_DE_L_OFFRE  \
#  0                 08/04/2024                   30/04/2024
#  1                 08/04/2024                   30/04/2024
#  2                 08/04/2024                   30/04/2024
#  3                 08/04/2024                   30/04/2024
#  4                 08/04/2024                   30/04/2024
#  ..                       ...                          ...
#  465               08/04/2024                   15/04/2024
#  466               08/04/2024                   15/04/2024
#  467               08/04/2024                   15/04/2024
#  468               08/04/2024                   15/04/2024
#  469               08/04/2024                   15/04/2024
#
#                                             Description  \
#  0    MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
#  1    MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
#  2    MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
#  3    MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
#  4    MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
#  ..                                                 ...
#  465  Description du posteLA MISSION D'ACTION CONTRE...
#  466  Description du posteLA MISSION D'ACTION CONTRE...
#  467  Description du posteLA MISSION D'ACTION CONTRE...
#  468  Description du posteLA MISSION D'ACTION CONTRE...
#  469  Description du posteLA MISSION D'ACTION CONTRE...
#
#                                       INTITULE_DU_POSTE  \
#  0    EXPERT DEVELOPPEMENT LOCAL - PLANIFICATION DU ...
#  1                                SUPERVISEUR RÉGIONNAL
#  2                               10 COMMERCIAUX (STAGE)
#  3                                   CONSULTANTS EN AGR
#  4                            NAVIGATIONAL WATCH RATING
#  ..                                                 ...
#  465                           CHARGE COMMUNICATION H/F
#  466                    RESPONSABLE RESSOURCES HUMANIES
#  467                     FORMATEUR ELECTRICITE BATIMENT
#  468    FORMATEUR EN COLLECTE ET TRAITEMENT DES DECHETS
#  469                                  COMMUNITY MANAGER
#
#                                              Sous_titre    Code Date_DEdition  \
#  0    exXicaa-tbrecruteEXPERT DEVELOPPEMENT LOCAL - ...  111900    08/04/2024
#  1    AMIFACIrecruteSUPERVISEUR RÉGIONNALDescription...  111864    05/04/2024
#  2    BORN COTE D'IVOIRErecrute10 COMMERCIAUX (STAGE...  111844    05/04/2024
#  3    ONG EICFrecruteDES CONSULTANTS EN AGRDescripti...  111829    04/04/2024
#  4    SERVIZI ENERGIA ITALIA (SEI)recruitNAVIGATIONA...  111814    04/04/2024
#  ..                                                 ...     ...           ...
#  465  IVOIRE FACILITY MANAGEMENTrecruteCHARGE COMMUN...  110615    01/03/2024
#  466  ACTUMEDIArecruteRESPONSABLE RESSOURCES HUMANIE...  110074    16/02/2024
#  467  INSTITUT PANAFRICAIN DES HAUTES ETUDES ET FORM...  108816    17/01/2024
#  468  INSTITUT PANAFRICAIN DES HAUTES ETUDES ET FORM...  107756    18/12/2023
#  469  Description du postea l'aide de votre smartpho...  105957    06/11/2023
#
#      Date_limite PAYS_DU_POSTE_DE_TRAVAIL  \
#  0    15/04/2024                   d'I...
#  1    15/04/2024                   d'I...
#  2    15/04/2024                  ABIDJAN
#  3    15/04/2024                    et...
#  4    27/04/2024                     O...
#  ..          ...                      ...
#  465  31/12/2024                 d'Ivoire
#  466  13/08/2024                 D'IVOIRE
#  467  29/08/2024                   d'I...
#  468  01/08/2024                  Abidjan
#  469  23/04/2024                 yopougon
#
#                                                     URL  \
#  0    https://emploi.educarriere.ci/nos-offres?page1...
#  1    https://emploi.educarriere.ci/nos-offres?page1...
#  2    https://emploi.educarriere.ci/nos-offres?page1...
#  3    https://emploi.educarriere.ci/nos-offres?page1...
#  4    https://emploi.educarriere.ci/nos-offres?page1...
#  ..                                                 ...
#  465  https://emploi.educarriere.ci/nos-offres?page1...
#  466  https://emploi.educarriere.ci/nos-offres?page1...
#  467  https://emploi.educarriere.ci/nos-offres?page1...
#  468  https://emploi.educarriere.ci/nos-offres?page1...
#  469  https://emploi.educarriere.ci/nos-offres?page1...
#
#      Unite_EXPERIENCE_PROFESSIONNELLE
#  0                                ans
#  1                                ans
#  2                                ans
#  3                                ans
#  4                                ans
#  ..                               ...
#  465                              ans
#  466                              ans
#  467                              ans
#  468                              ans
#  469                              ans
#
#  [470 rows x 18 columns],
#                          INTITULE_DU_POSTE                   Entreprise  \
#  0    Gestionnaire des Ressources Humaines                          NaN
#  1    Gestionnaire des Ressources Humaines                          NaN
#  2    Gestionnaire des Ressources Humaines                          NaN
#  3    Gestionnaire des Ressources Humaines                          NaN
#  4    Gestionnaire des Ressources Humaines                          NaN
#  ..                                    ...                          ...
#  769                   Maintenance Officer  OLAM FOOD Ingrédients (OFI)
#  770                   Maintenance Officer  OLAM FOOD Ingrédients (OFI)
#  771                   Maintenance Officer  OLAM FOOD Ingrédients (OFI)
#  772                  Production in Charge  OLAM FOOD Ingrédients (OFI)
#  773                  Conducteur Chaudière  OLAM FOOD Ingrédients (OFI)
#
#      PAYS_DU_POSTE_DE_TRAVAIL DATE_DE_DEBUT_DE_L_OFFRE  \
#  0              Côte d'ivoire                  24 Mars
#  1              Côte d'ivoire                  24 Mars
#  2              Côte d'ivoire                  24 Mars
#  3              Côte d'ivoire                  24 Mars
#  4              Côte d'ivoire                  24 Mars
#  ..                       ...                      ...
#  769            Côte d'ivoire               31 Janvier
#  770            Côte d'ivoire               31 Janvier
#  771            Côte d'ivoire               31 Janvier
#  772            Côte d'ivoire               06 Février
#  773            Côte d'ivoire               31 Janvier
#
#                                  Niveau Experience_lettre  \
#  0    Manager / Responsable département        6 à 10 ans
#  1    Manager / Responsable département        6 à 10 ans
#  2    Manager / Responsable département        6 à 10 ans
#  3    Manager / Responsable département        6 à 10 ans
#  4    Manager / Responsable département        6 à 10 ans
#  ..                                 ...               ...
#  769             Confirmé / Expérimenté        6 à 10 ans
#  770             Confirmé / Expérimenté        6 à 10 ans
#  771             Confirmé / Expérimenté        6 à 10 ans
#  772             Confirmé / Expérimenté        6 à 10 ans
#  773                  Débutant / Junior         3 à 5 ans
#
#                                                     url  \
#  0    https://www.novojob.com/cote-d-ivoire/offres-d...
#  1    https://www.novojob.com/cote-d-ivoire/offres-d...
#  2    https://www.novojob.com/cote-d-ivoire/offres-d...
#  3    https://www.novojob.com/cote-d-ivoire/offres-d...
#  4    https://www.novojob.com/cote-d-ivoire/offres-d...
#  ..                                                 ...
#  769  https://www.novojob.com/cote-d-ivoire/offres-d...
#  770  https://www.novojob.com/cote-d-ivoire/offres-d...
#  771  https://www.novojob.com/cote-d-ivoire/offres-d...
#  772  https://www.novojob.com/cote-d-ivoire/offres-d...
#  773  https://www.novojob.com/cote-d-ivoire/offres-d...
#
#                                SITE_WEB_DE_L_ENTREPRISE  \
#  0    https://www.novojob.com/cote-d-ivoire/offres-d...
#  1    https://www.novojob.com/cote-d-ivoire/offres-d...
#  2    https://www.novojob.com/cote-d-ivoire/offres-d...
#  3    https://www.novojob.com/cote-d-ivoire/offres-d...
#  4    https://www.novojob.com/cote-d-ivoire/offres-d...
#  ..                                                 ...
#  769  https://www.novojob.com/cote-d-ivoire/offres-d...
#  770  https://www.novojob.com/cote-d-ivoire/offres-d...
#  771  https://www.novojob.com/cote-d-ivoire/offres-d...
#  772  https://www.novojob.com/cote-d-ivoire/offres-d...
#  773  https://www.novojob.com/cote-d-ivoire/offres-d...
#
#      LIEU_DU_POSTE_DE_TRAVAIL DATE_D_EXPIRATION_DE_L_OFFRE  \
#  0     Abidjan, Côte d'ivoire                      22 Juin
#  1     Abidjan, Côte d'ivoire                      22 Juin
#  2     Abidjan, Côte d'ivoire                      22 Juin
#  3     Abidjan, Côte d'ivoire                      22 Juin
#  4     Abidjan, Côte d'ivoire                      22 Juin
#  ..                       ...                          ...
#  769    Bouake, Côte d'ivoire                     30 Avril
#  770    Bouake, Côte d'ivoire                     30 Avril
#  771    Bouake, Côte d'ivoire                     30 Avril
#  772    Bouake, Côte d'ivoire                       06 Mai
#  773   Abidjan, Côte d'ivoire                     30 Avril
#
#                         Niveau de poste      BRANCHE_D_ACTIVITE  \
#  0    Manager / Responsable département                Services
#  1    Manager / Responsable département                Services
#  2    Manager / Responsable département                Services
#  3    Manager / Responsable département                Services
#  4    Manager / Responsable département                Services
#  ..                                 ...                     ...
#  769             Confirmé / Expérimenté  Distribution, Commerce
#  770             Confirmé / Expérimenté  Distribution, Commerce
#  771             Confirmé / Expérimenté  Distribution, Commerce
#  772             Confirmé / Expérimenté  Distribution, Commerce
#  773                  Débutant / Junior  Distribution, Commerce
#
#                                            Texte_fourni  \
#  0    Entreprise spécialisée dans l’ingénierie mécan...
#  1    Entreprise spécialisée dans l’ingénierie mécan...
#  2    Entreprise spécialisée dans l’ingénierie mécan...
#  3    Entreprise spécialisée dans l’ingénierie mécan...
#  4    Entreprise spécialisée dans l’ingénierie mécan...
#  ..                                                 ...
#  769  Position within the structure :Position based ...
#  770  Position within the structure :Position based ...
#  771  Position within the structure :Position based ...
#  772  Présentation de l’entreprise \nOLAM FOOD ingre...
#  773  Position dans la structure: Poste basé à San P...
#
#         Niveau d'étude (diplome)  NOMBRE_DE_POSTES_A_POURVOIR  \
#  0                           NaN                          NaN
#  1                           NaN                          NaN
#  2                           NaN                          NaN
#  3                           NaN                          NaN
#  4                           NaN                          NaN
#  ..                          ...                          ...
#  769   Formation Professionnelle                          1.0
#  770   Formation Professionnelle                          1.0
#  771   Formation Professionnelle                          1.0
#  772  Master 1, Licence  Bac + 4                          1.0
#  773   Formation Professionnelle                          1.0
#
#      TYPE_DE_CONTRAT_DU_POSTE RAISON_SOCIALE_DE_L_ENTREPRISE  \
#  0                        NaN                            NaN
#  1                        NaN                            NaN
#  2                        NaN                            NaN
#  3                        NaN                            NaN
#  4                        NaN                            NaN
#  ..                       ...                            ...
#  769                      CDI                            NaN
#  770                      CDI                            NaN
#  771                      CDI                            NaN
#  772                      CDI                            NaN
#  773                      CDI                            NaN
#
#      VILLE_DU_POSTE_DE_TRAVAIL
#  0                     Abidjan
#  1                     Abidjan
#  2                     Abidjan
#  3                     Abidjan
#  4                     Abidjan
#  ..                        ...
#  769                    Bouake
#  770                    Bouake
#  771                    Bouake
#  772                    Bouake
#  773                   Abidjan
#
#  [774 rows x 18 columns],
#                                        INTITULE_DU_POSTE  \
#  0     Solidaridad West Africa recrute Conseiller(e) ...
#  1     Société Générale Côte D’ivoire recrute Attaché...
#  2                      Agent WAVE dans plusieurs Villes
#  3        IVAN’S GROUP recrute Responsable de Trésorerie
#  4     Stagiaire Assistant Communication et Marketing...
#  ...                                                 ...
#  9277  PSI CI recrute 02 CONSEILLERS TECHNIQUES RÉGIO...
#  9278   La Banque Atlantique recrute de nouveaux profils
#  9279    Les Orchidées Rouges recrutent Chargé de projet
#  9280                               DIRECTEUR DES ETUDES
#  9281      STAGIAIRE COMPTABLE ET GESTIONNAIRE DE STOCKS
#
#       TYPE_DE_CONTRAT_DU_POSTE DATE_DE_PUBLICATION  \
#  0                      Emploi        8 avril 2024
#  1                      Emploi        8 avril 2024
#  2                     Contrat        8 avril 2024
#  3                      Emploi        8 avril 2024
#  4                       Stage        8 avril 2024
#  ...                       ...                 ...
#  9277                   Emploi   20 septembre 2021
#  9278                   Emploi   20 septembre 2021
#  9279                   Emploi   20 septembre 2021
#  9280                   Emploi   20 septembre 2021
#  9281                    Stage   20 septembre 2021
#
#       DATE_D_EXPIRATION_DE_L_OFFRE               CATEGORIE  \
#  0                   23 avril 2024                     NaN
#  1                   23 avril 2024                  Banque
#  2                   23 avril 2024         Commerce/Ventes
#  3                   23 avril 2024   Finances/Comptabilité
#  4                   23 avril 2024           Communication
#  ...                           ...                     ...
#  9277            24 septembre 2021          Médecine/Santé
#  9278            24 septembre 2021                  Banque
#  9279            24 septembre 2021                     NaN
#  9280            24 septembre 2021  Education/Enseignement
#  9281            24 septembre 2021   Finances/Comptabilité
#
#                                                 EmailURL  \
#  0     https://projobivoire.com/jobs/solidaridad-west...
#  1     https://projobivoire.com/jobs/societe-generale...
#  2     https://projobivoire.com/jobs/agent-wave-dans-...
#  3     https://projobivoire.com/jobs/ivans-group-recr...
#  4     https://projobivoire.com/jobs/stagiaire-assist...
#  ...                                                 ...
#  9277  https://projobivoire.com/jobs/psi-ci-recrute-0...
#  9278  https://projobivoire.com/jobs/la-banque-atlant...
#  9279  https://projobivoire.com/jobs/les-orchidees-ro...
#  9280  https://projobivoire.com/jobs/directeur-des-et...
#  9281  https://projobivoire.com/jobs/stagiaire-compta...
#
#                  SITE_WEB_DE_L_ENTREPRISE
#  0       https://projobivoire.com/page/0/
#  1       https://projobivoire.com/page/0/
#  2       https://projobivoire.com/page/0/
#  3       https://projobivoire.com/page/0/
#  4       https://projobivoire.com/page/0/
#  ...                                  ...
#  9277  https://projobivoire.com/page/545/
#  9278  https://projobivoire.com/page/545/
#  9279  https://projobivoire.com/page/545/
#  9280  https://projobivoire.com/page/545/
#  9281  https://projobivoire.com/page/545/
#
#  [9282 rows x 7 columns],
#                                       INTITULE_DU_POSTE  \
#  0    Country Technical Sales Manager – West Africa ...
#  1                                       Chauffeur Moto
#  2                         Chef comptable assurance vie
#  3                   Assistante RH / Assistant RH (H/F)
#  4                        Agent de sécurite gardiennage
#  ..                                                 ...
#  151                 Mécanicien / Mécanicienne agricole
#  152                                Credit Risk Officer
#  153                  Senior Consultant, Client Success
#  154                        Technicien chauffagiste H/F
#  155                Ivory Coast Cluster Revenue Manager
#
#                   LIEU_DU_POSTE_DE_TRAVAIL     RAISON_SOCIALE_DE_L_ENTREPRISE  \
#  0                        Abidjan, Abidjan                      Claire Joster
#  1                        Abidjan, Abidjan                        Deals Jumia
#  2                        Abidjan, Abidjan                             Senjob
#  3                        Abidjan, Abidjan                                RMO
#  4                        Abidjan, Abidjan                     ESMA (ABIDJAN)
#  ..                                    ...                                ...
#  151                      Abidjan, Lagunes                           Temporis
#  152                      Abidjan, Lagunes  09220 Citibank Cote d'Ivoire S.A.
#  153               Abidjan, Lagunes Region                               VISA
#  154  Abidjan, Abidjan Autonomous District                             Acorus
#  155  Abidjan, Abidjan Autonomous District                              ACCOR
#
#                                    DESCRIPTION_DU_POSTE  \
#  0    PresentaciónClaire Joster is a headhunting fir...
#  1    Description. NE PAYEZ AUCUN FRAIS DE DOSSIERS ...
#  2    Au sein de la Direction Administrative et Fina...
#  3    Le PosteRecruteurImplanté en Afrique, RMO vous...
#  4    Description de l'emploiEn quoi consiste l'empl...
#  ..                                                 ...
#  151  TEMPORIS Vendée Littoral, plus que des agences...
#  152  The Country Risk Senior Analyst is a seasoned ...
#  153  Job Description And ResponsibilitiesThis is an...
#  154  LE POSTE..️ Qui dit croissance, dit création d...
#  155  Job DescriptionProperties Abidjan Accor Hotels...
#
#                                SITE_WEB_DE_L_ENTREPRISE
#  0    https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
#  1    https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
#  2    https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
#  3    https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
#  4    https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
#  ..                                                 ...
#  151  https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
#  152  https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
#  153  https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
#  154  https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
#  155  https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
#
#  [156 rows x 5 columns],
#                             Poste  Entreprise        Date  \
#  0     Technicien Support OPS H/F     INSTAHR  07.04.2024
#  1     Technicien Support OPS H/F     INSTAHR  07.04.2024
#  2     Technicien Support OPS H/F     INSTAHR  07.04.2024
#  3     Technicien Support OPS H/F     INSTAHR  07.04.2024
#  4     Technicien Support OPS H/F     INSTAHR  07.04.2024
#  ...                          ...         ...         ...
#  2461         Directeur Technique  AFRICAWORK  23.02.2024
#  2462         Directeur Technique  AFRICAWORK  23.02.2024
#  2463         Directeur Technique  AFRICAWORK  23.02.2024
#  2464         Directeur Technique  AFRICAWORK  23.02.2024
#  2465         Directeur Technique  AFRICAWORK  23.02.2024
#
#                                              Description  Région  \
#  0     Instahr, une entreprise canadienne, recrute po...     NaN
#  1     Instahr, une entreprise canadienne, recrute po...     NaN
#  2     Instahr, une entreprise canadienne, recrute po...     NaN
#  3     Instahr, une entreprise canadienne, recrute po...     NaN
#  4     Instahr, une entreprise canadienne, recrute po...     NaN
#  ...                                                 ...     ...
#  2461  MISSION PRINCIPALEAssurer le suivi des interve...     NaN
#  2462  MISSION PRINCIPALEAssurer le suivi des interve...     NaN
#  2463  MISSION PRINCIPALEAssurer le suivi des interve...     NaN
#  2464  MISSION PRINCIPALEAssurer le suivi des interve...     NaN
#  2465  MISSION PRINCIPALEAssurer le suivi des interve...     NaN
#
#                                                      URL  \
#  0     https://www.emploi.ci/recherche-jobs-cote-ivoi...
#  1     https://www.emploi.ci/recherche-jobs-cote-ivoi...
#  2     https://www.emploi.ci/recherche-jobs-cote-ivoi...
#  3     https://www.emploi.ci/recherche-jobs-cote-ivoi...
#  4     https://www.emploi.ci/recherche-jobs-cote-ivoi...
#  ...                                                 ...
#  2461  https://www.emploi.ci/recherche-jobs-cote-ivoi...
#  2462  https://www.emploi.ci/recherche-jobs-cote-ivoi...
#  2463  https://www.emploi.ci/recherche-jobs-cote-ivoi...
#  2464  https://www.emploi.ci/recherche-jobs-cote-ivoi...
#  2465  https://www.emploi.ci/recherche-jobs-cote-ivoi...
#
#                                               Offre_Link
#  0     https://www.emploi.ci/offre-emploi-cote-ivoire...
#  1     https://www.emploi.ci/offre-emploi-cote-ivoire...
#  2     https://www.emploi.ci/offre-emploi-cote-ivoire...
#  3     https://www.emploi.ci/offre-emploi-cote-ivoire...
#  4     https://www.emploi.ci/offre-emploi-cote-ivoire...
#  ...                                                 ...
#  2461  https://www.emploi.ci/offre-emploi-cote-ivoire...
#  2462  https://www.emploi.ci/offre-emploi-cote-ivoire...
#  2463  https://www.emploi.ci/offre-emploi-cote-ivoire...
#  2464  https://www.emploi.ci/offre-emploi-cote-ivoire...
#  2465  https://www.emploi.ci/offre-emploi-cote-ivoire...
#
#  [2466 rows x 7 columns],
#                                      INTITULE_DU_POSTE  \
#  0   (Senior) Industry Specialist – Tourism (Hospit...
#  1   Associate Environmental and Social Development...
#  2   Associate Environmental and Social Development...
#  3                        Associate Investment Officer
#  4                        Associate Investment Officer
#  5                        Associate Investment Officer
#  6     Associate Investment Officer/Investment Officer
#  7     Associate Operations Officer/Operations Officer
#  8                                    Business Analyst
#  9                              Climate Change Analyst
#  10  Climate Change Analyst (Programming and Innova...
#  11        Corporate Procurement Category Analyst HRPS
#  12        Corporate Procurement Category Manager HRPS
#  13                                            Counsel
#  14                                            Counsel
#  15                                    Country Officer
#  16                                             Driver
#  17                                             Driver
#  18                                     E T Consultant
#  19                                     E T Consultant
#  20  (Senior) Industry Specialist – Tourism (Hospit...
#  21  Associate Environmental and Social Development...
#  22  Associate Environmental and Social Development...
#  23                       Associate Investment Officer
#  24                       Associate Investment Officer
#  25                       Associate Investment Officer
#  26    Associate Investment Officer/Investment Officer
#  27    Associate Operations Officer/Operations Officer
#  28                                   Business Analyst
#  29                             Climate Change Analyst
#  30  Climate Change Analyst (Programming and Innova...
#  31        Corporate Procurement Category Analyst HRPS
#  32        Corporate Procurement Category Manager HRPS
#  33                                            Counsel
#  34                                            Counsel
#  35                                    Country Officer
#  36                                             Driver
#  37                                             Driver
#  38                                     E T Consultant
#  39                                     E T Consultant
#  40  (Senior) Industry Specialist – Tourism (Hospit...
#  41  Associate Environmental and Social Development...
#  42  Associate Environmental and Social Development...
#  43                       Associate Investment Officer
#  44                       Associate Investment Officer
#  45                       Associate Investment Officer
#  46    Associate Investment Officer/Investment Officer
#  47    Associate Operations Officer/Operations Officer
#  48                                   Business Analyst
#  49                             Climate Change Analyst
#  50  Climate Change Analyst (Programming and Innova...
#  51        Corporate Procurement Category Analyst HRPS
#  52        Corporate Procurement Category Manager HRPS
#  53                                            Counsel
#  54                                            Counsel
#  55                                    Country Officer
#  56                                             Driver
#  57                                             Driver
#  58                                     E T Consultant
#  59                                     E T Consultant
#
#          LIEU_DU_POSTE_DE_TRAVAIL                        SECTEUR  \
#  0   Washington, DC,United States                     Investment
#  1                 Hanoi,Viet Nam                    Environment
#  2                   Mumbai,India                    Environment
#  3                Belgrade,Serbia                     Investment
#  4       Mexico City,Mexico  More                     Investment
#  5               Istanbul,Turkiye                     Investment
#  6              Cairo,Egypt  More                     Investment
#  7                  Nairobi,Kenya                         Gender
#  8                  Chennai,India         Information Technology
#  9   Washington, DC,United States                 Climate Change
#  10  Washington, DC,United States                 Climate Change
#  11                Sofia,Bulgaria                    Procurement
#  12  Washington, DC,United States                    Procurement
#  13                 Dakar,Senegal                          Legal
#  14  Washington, DC,United States                          Legal
#  15         Freetown,Sierra Leone                          Other
#  16                  Kyiv,Ukraine  Administration/Office Support
#  17            Panama City,Panama  Administration/Office Support
#  18              Brussels,Belgium                 Transportation
#  19  Washington, DC,United States    Health/Nutrition/Population
#  20  Washington, DC,United States                     Investment
#  21                Hanoi,Viet Nam                    Environment
#  22                  Mumbai,India                    Environment
#  23               Belgrade,Serbia                     Investment
#  24      Mexico City,Mexico  More                     Investment
#  25              Istanbul,Turkiye                     Investment
#  26             Cairo,Egypt  More                     Investment
#  27                 Nairobi,Kenya                         Gender
#  28                 Chennai,India         Information Technology
#  29  Washington, DC,United States                 Climate Change
#  30  Washington, DC,United States                 Climate Change
#  31                Sofia,Bulgaria                    Procurement
#  32  Washington, DC,United States                    Procurement
#  33                 Dakar,Senegal                          Legal
#  34  Washington, DC,United States                          Legal
#  35         Freetown,Sierra Leone                          Other
#  36                  Kyiv,Ukraine  Administration/Office Support
#  37            Panama City,Panama  Administration/Office Support
#  38              Brussels,Belgium                 Transportation
#  39  Washington, DC,United States    Health/Nutrition/Population
#  40  Washington, DC,United States                     Investment
#  41                Hanoi,Viet Nam                    Environment
#  42                  Mumbai,India                    Environment
#  43               Belgrade,Serbia                     Investment
#  44      Mexico City,Mexico  More                     Investment
#  45              Istanbul,Turkiye                     Investment
#  46             Cairo,Egypt  More                     Investment
#  47                 Nairobi,Kenya                         Gender
#  48                 Chennai,India         Information Technology
#  49  Washington, DC,United States                 Climate Change
#  50  Washington, DC,United States                 Climate Change
#  51                Sofia,Bulgaria                    Procurement
#  52  Washington, DC,United States                    Procurement
#  53                 Dakar,Senegal                          Legal
#  54  Washington, DC,United States                          Legal
#  55         Freetown,Sierra Leone                          Other
#  56                  Kyiv,Ukraine  Administration/Office Support
#  57            Panama City,Panama  Administration/Office Support
#  58              Brussels,Belgium                 Transportation
#  59  Washington, DC,United States    Health/Nutrition/Population
#
#     DATE_D_EXPIRATION_DE_L_OFFRE
#  0                     4/25/2024
#  1                     4/18/2024
#  2                     4/20/2024
#  3                     4/10/2024
#  4                     4/15/2024
#  5                     4/17/2024
#  6                     4/16/2024
#  7                     4/20/2024
#  8                     4/28/2024
#  9                     4/10/2024
#  10                    4/10/2024
#  11                    4/19/2024
#  12                    4/19/2024
#  13                    4/15/2024
#  14                    4/19/2024
#  15                    4/17/2024
#  16                    4/15/2024
#  17                    4/17/2024
#  18                     4/9/2024
#  19                    4/15/2024
#  20                    4/25/2024
#  21                    4/18/2024
#  22                    4/20/2024
#  23                    4/10/2024
#  24                    4/15/2024
#  25                    4/17/2024
#  26                    4/16/2024
#  27                    4/20/2024
#  28                    4/28/2024
#  29                    4/10/2024
#  30                    4/10/2024
#  31                    4/19/2024
#  32                    4/19/2024
#  33                    4/15/2024
#  34                    4/19/2024
#  35                    4/17/2024
#  36                    4/15/2024
#  37                    4/17/2024
#  38                     4/9/2024
#  39                    4/15/2024
#  40                    4/25/2024
#  41                    4/18/2024
#  42                    4/20/2024
#  43                    4/10/2024
#  44                    4/15/2024
#  45                    4/17/2024
#  46                    4/16/2024
#  47                    4/20/2024
#  48                    4/28/2024
#  49                    4/10/2024
#  50                    4/10/2024
#  51                    4/19/2024
#  52                    4/19/2024
#  53                    4/15/2024
#  54                    4/19/2024
#  55                    4/17/2024
#  56                    4/15/2024
#  57                    4/17/2024
#  58                     4/9/2024
#  59                    4/15/2024  ,
#                                         INTITULE_DU_POSTE  \
#  0                      Le PAM recrute pour ces 2 postes
#  1                      Le PAM recrute pour ces 2 postes
#  2      L’Organisation internationale URC recrute pour...
#  3            L’UNION AFRICAINE UA recrute pour ce poste
#  4      Le Centre du riz pour l’Afrique AfricaRice rec...
#  ...                                                  ...
#  39309                       ACTED recrute pour ce poste
#  39310  Médecins Sans Frontières MSF recrute pour ce p...
#  39311                      FHI360 recrute pour ce poste
#  39312           L’ONG Le GRET recrute pour ces 3 postes
#  39313                 Le PNUD recrute pour ces 2 postes
#
#                                              URL_DU_POSTE  \
#  0      https://yop.l-frii.com/emploi/le-pam-recrute-p...
#  1      https://yop.l-frii.com/emploi/le-pam-recrute-p...
#  2      https://yop.l-frii.com/emploi/lorganisation-in...
#  3      https://yop.l-frii.com/emploi/lunion-africaine...
#  4      https://yop.l-frii.com/emploi/le-centre-du-riz...
#  ...                                                  ...
#  39309  https://yop.l-frii.com/emploi/acted-recrute-po...
#  39310  https://yop.l-frii.com/emploi/medecins-sans-fr...
#  39311  https://yop.l-frii.com/emploi/fhi360-recrute-p...
#  39312  https://yop.l-frii.com/emploi/long-le-gret-rec...
#  39313  https://yop.l-frii.com/emploi/le-pnud-recrute-...
#
#                                                 Job Image  \
#  0      https://yop.l-frii.com/wp-content/uploads/2024...
#  1      https://yop.l-frii.com/wp-content/uploads/2024...
#  2      https://yop.l-frii.com/wp-content/uploads/2024...
#  3      https://yop.l-frii.com/wp-content/uploads/2024...
#  4      https://yop.l-frii.com/wp-content/uploads/2024...
#  ...                                                  ...
#  39309  https://yop.l-frii.com/wp-content/uploads/2022...
#  39310  https://yop.l-frii.com/wp-content/uploads/2022...
#  39311  https://yop.l-frii.com/wp-content/uploads/2022...
#  39312  https://yop.l-frii.com/wp-content/uploads/2021...
#  39313  https://yop.l-frii.com/wp-content/uploads/2022...
#
#                                           Source URL DATE_DE_DEBUT_DE_L_OFFRE  \
#  0         https://yop.l-frii.com/offres-demplois/0/            08 Avril 2024
#  1         https://yop.l-frii.com/offres-demplois/1/            08 Avril 2024
#  2         https://yop.l-frii.com/offres-demplois/0/            08 Avril 2024
#  3         https://yop.l-frii.com/offres-demplois/0/            08 Avril 2024
#  4         https://yop.l-frii.com/offres-demplois/0/            08 Avril 2024
#  ...                                             ...                      ...
#  39309  https://yop.l-frii.com/offres-demplois/3275/          16 Janvier 2022
#  39310  https://yop.l-frii.com/offres-demplois/3275/          17 Janvier 2022
#  39311  https://yop.l-frii.com/offres-demplois/3275/          17 Janvier 2022
#  39312  https://yop.l-frii.com/offres-demplois/3275/          17 Janvier 2022
#  39313  https://yop.l-frii.com/offres-demplois/3275/          17 Janvier 2022
#
#         NOMBRE_DE_POSTE_DE_TRAVAIL       Titre du Poste  \
#  0                             2.0  2023 © L-FRII MEDIA
#  1                             2.0  2023 © L-FRII MEDIA
#  2                             2.0  2023 © L-FRII MEDIA
#  3                             NaN  2023 © L-FRII MEDIA
#  4                            10.0  2023 © L-FRII MEDIA
#  ...                           ...                  ...
#  39309                         NaN  2023 © L-FRII MEDIA
#  39310                         NaN  2023 © L-FRII MEDIA
#  39311                         NaN  2023 © L-FRII MEDIA
#  39312                         3.0  2023 © L-FRII MEDIA
#  39313                         2.0  2023 © L-FRII MEDIA
#
#                           Niveau Requis Année d'Expérience Requise  \
#  0      Diplôme universitaire supérieur               2 ans, 6 ans
#  1      Diplôme universitaire supérieur               2 ans, 6 ans
#  2                                  NaN                        NaN
#  3                               Master                        NaN
#  4                                  NaN                        NaN
#  ...                                ...                        ...
#  39309                  Licence, Master                      5 ans
#  39310                         Doctorat                      2 ans
#  39311                          BAC + 3                      5 ans
#  39312  Diplôme universitaire supérieur                      3 ans
#  39313                              NaN                        NaN
#
#                        Lieu du Travail Date de Soumission annee_min annee_max  \
#  0                      Guinée / Bénin         21/04/2024         2         6
#  1                      Guinée / Bénin         21/04/2024         2         6
#  2                     Abuja , Nigéria                NaN       NaN       NaN
#  3                             Algérie         08/05/2024       NaN       NaN
#  4      Côte d'Ivoire / Sénégal / Togo                NaN       NaN       NaN
#  ...                               ...                ...       ...       ...
#  39309                             NaN                NaN         5         5
#  39310       Burkina-Faso, Mali, Niger         07/02/2022         2         2
#  39311                 Cotonou - Bénin         07/02/2022         5         5
#  39312                          Guinée         30/01/2022         3         3
#  39313                             NaN         31/01/2022       NaN       NaN
#
#               LIEU_DU_POSTE_DE_TRAVAIL        PAYS_DU_POSTE_DE_TRAVAIL
#  0                      Guinée / Bénin                  Guinée / Bénin
#  1                      Guinée / Bénin                  Guinée / Bénin
#  2                              Abuja                          Nigéria
#  3                             Algérie                         Algérie
#  4      Côte d'Ivoire / Sénégal / Togo  Côte d'Ivoire / Sénégal / Togo
#  ...                               ...                             ...
#  39309                             NaN                             NaN
#  39310                    Burkina-Faso                     Mali, Niger
#  39311                 Cotonou - Bénin                 Cotonou - Bénin
#  39312                          Guinée                          Guinée
#  39313                             NaN                             NaN
#
#  [39314 rows x 15 columns]]

# %%
# Concaténer les DataFrames en un seul
result = pd.concat(frames, ignore_index=True)
result
# Out:
#                                       BRANCHE_D_ACTIVITE  \
# 0      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 1      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 2      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 3      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 4      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# ...                                                  ...
# 52517                                                NaN
# 52518                                                NaN
# 52519                                                NaN
# 52520                                                NaN
# 52521                                                NaN
#
#       TYPE_DE_CONTRAT_DU_POSTE    SPECIALITE DIPLOME  \
# 0                       Emploi  Informatique   BAC+5
# 1                       Emploi  Informatique   BAC+5
# 2                       Emploi  Informatique   BAC+5
# 3                       Emploi  Informatique   BAC+5
# 4                       Emploi  Informatique   BAC+5
# ...                        ...           ...     ...
# 52517                      NaN           NaN     NaN
# 52518                      NaN           NaN     NaN
# 52519                      NaN           NaN     NaN
# 52520                      NaN           NaN     NaN
# 52521                      NaN           NaN     NaN
#
#        EXPERIENCE_PROFESSIONNELLE LIEU_DU_POSTE_DE_TRAVAIL  \
# 0                             5.0            Côte d'Ivoire
# 1                             5.0            Côte d'Ivoire
# 2                             5.0            Côte d'Ivoire
# 3                             5.0            Côte d'Ivoire
# 4                             5.0            Côte d'Ivoire
# ...                           ...                      ...
# 52517                         NaN                      NaN
# 52518                         NaN             Burkina-Faso
# 52519                         NaN          Cotonou - Bénin
# 52520                         NaN                   Guinée
# 52521                         NaN                      NaN
#
#                                 SITE_WEB_DE_L_ENTREPRISE  \
# 0      https://emploi.educarriere.ci/offre-116075-exp...
# 1      https://emploi.educarriere.ci/offre-116075-exp...
# 2      https://emploi.educarriere.ci/offre-116075-exp...
# 3      https://emploi.educarriere.ci/offre-116075-exp...
# 4      https://emploi.educarriere.ci/offre-116075-exp...
# ...                                                  ...
# 52517                                                NaN
# 52518                                                NaN
# 52519                                                NaN
# 52520                                                NaN
# 52521                                                NaN
#
#       DATE_DE_DEBUT_DE_L_OFFRE DATE_D_EXPIRATION_DE_L_OFFRE  \
# 0                   08/04/2024                   30/04/2024
# 1                   08/04/2024                   30/04/2024
# 2                   08/04/2024                   30/04/2024
# 3                   08/04/2024                   30/04/2024
# 4                   08/04/2024                   30/04/2024
# ...                        ...                          ...
# 52517          16 Janvier 2022                          NaN
# 52518          17 Janvier 2022                          NaN
# 52519          17 Janvier 2022                          NaN
# 52520          17 Janvier 2022                          NaN
# 52521          17 Janvier 2022                          NaN
#
#                                              Description  ...  \
# 0      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...
# 1      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...
# 2      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...
# 3      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...
# 4      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...
# ...                                                  ...  ...
# 52517                                                NaN  ...
# 52518                                                NaN  ...
# 52519                                                NaN  ...
# 52520                                                NaN  ...
# 52521                                                NaN  ...
#
#                                                Job Image  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 52517  https://yop.l-frii.com/wp-content/uploads/2022...
# 52518  https://yop.l-frii.com/wp-content/uploads/2022...
# 52519  https://yop.l-frii.com/wp-content/uploads/2022...
# 52520  https://yop.l-frii.com/wp-content/uploads/2021...
# 52521  https://yop.l-frii.com/wp-content/uploads/2022...
#
#                                          Source URL  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 52517  https://yop.l-frii.com/offres-demplois/3275/
# 52518  https://yop.l-frii.com/offres-demplois/3275/
# 52519  https://yop.l-frii.com/offres-demplois/3275/
# 52520  https://yop.l-frii.com/offres-demplois/3275/
# 52521  https://yop.l-frii.com/offres-demplois/3275/
#
#        NOMBRE_DE_POSTE_DE_TRAVAIL       Titre du Poste  \
# 0                             NaN                  NaN
# 1                             NaN                  NaN
# 2                             NaN                  NaN
# 3                             NaN                  NaN
# 4                             NaN                  NaN
# ...                           ...                  ...
# 52517                         NaN  2023 © L-FRII MEDIA
# 52518                         NaN  2023 © L-FRII MEDIA
# 52519                         NaN  2023 © L-FRII MEDIA
# 52520                         3.0  2023 © L-FRII MEDIA
# 52521                         2.0  2023 © L-FRII MEDIA
#
#                          Niveau Requis Année d'Expérience Requise  \
# 0                                  NaN                        NaN
# 1                                  NaN                        NaN
# 2                                  NaN                        NaN
# 3                                  NaN                        NaN
# 4                                  NaN                        NaN
# ...                                ...                        ...
# 52517                  Licence, Master                      5 ans
# 52518                         Doctorat                      2 ans
# 52519                          BAC + 3                      5 ans
# 52520  Diplôme universitaire supérieur                      3 ans
# 52521                              NaN                        NaN
#
#                  Lieu du Travail Date de Soumission annee_min annee_max
# 0                            NaN                NaN       NaN       NaN
# 1                            NaN                NaN       NaN       NaN
# 2                            NaN                NaN       NaN       NaN
# 3                            NaN                NaN       NaN       NaN
# 4                            NaN                NaN       NaN       NaN
# ...                          ...                ...       ...       ...
# 52517                        NaN                NaN         5         5
# 52518  Burkina-Faso, Mali, Niger         07/02/2022         2         2
# 52519            Cotonou - Bénin         07/02/2022         5         5
# 52520                     Guinée         30/01/2022         3         3
# 52521                        NaN         31/01/2022       NaN       NaN
#
# [52522 rows x 48 columns]

# %%
result.columns affiche Index(['BRANCHE_D_ACTIVITE', 'TYPE_DE_CONTRAT_DU_POSTE', 'SPECIALITE',
       'DIPLOME', 'EXPERIENCE_PROFESSIONNELLE', 'LIEU_DU_POSTE_DE_TRAVAIL',
       'SITE_WEB_DE_L_ENTREPRISE', 'DATE_DE_DEBUT_DE_L_OFFRE',
       'DATE_D_EXPIRATION_DE_L_OFFRE', 'Description', 'INTITULE_DU_POSTE',
       'Sous_titre', 'Code', 'Date_DEdition', 'Date_limite',
       'PAYS_DU_POSTE_DE_TRAVAIL', 'URL', 'Unite_EXPERIENCE_PROFESSIONNELLE',
       'Entreprise', 'Niveau', 'Experience_lettre', 'url', 'Niveau de poste',
       'Texte_fourni', 'Niveau d'étude (diplome)',
       'NOMBRE_DE_POSTES_A_POURVOIR', 'RAISON_SOCIALE_DE_L_ENTREPRISE',
       'VILLE_DU_POSTE_DE_TRAVAIL', 'DATE_DE_PUBLICATION', 'CATEGORIE',
       'EmailURL', 'DESCRIPTION_DU_POSTE', 'Poste', 'Date', 'Région',
       'Offre_Link', 'SECTEUR', 'URL_DU_POSTE', 'Job Image', 'Source URL',
       'NOMBRE_DE_POSTE_DE_TRAVAIL', 'Titre du Poste', 'Niveau Requis',
       'Année d'Expérience Requise', 'Lieu du Travail', 'Date de Soumission',
       'annee_min', 'annee_max'],
      dtype='object')
# Out:
# Index(['BRANCHE_D_ACTIVITE', 'TYPE_DE_CONTRAT_DU_POSTE', 'SPECIALITE',
#        'DIPLOME', 'EXPERIENCE_PROFESSIONNELLE', 'LIEU_DU_POSTE_DE_TRAVAIL',
#        'SITE_WEB_DE_L_ENTREPRISE', 'DATE_DE_DEBUT_DE_L_OFFRE',
#        'DATE_D_EXPIRATION_DE_L_OFFRE', 'Description', 'INTITULE_DU_POSTE',
#        'Sous_titre', 'Code', 'Date_DEdition', 'Date_limite',
#        'PAYS_DU_POSTE_DE_TRAVAIL', 'URL', 'Unite_EXPERIENCE_PROFESSIONNELLE',
#        'Entreprise', 'Niveau', 'Experience_lettre', 'url', 'Niveau de poste',
#        'Texte_fourni', 'Niveau d'étude (diplome)',
#        'NOMBRE_DE_POSTES_A_POURVOIR', 'RAISON_SOCIALE_DE_L_ENTREPRISE',
#        'VILLE_DU_POSTE_DE_TRAVAIL', 'DATE_DE_PUBLICATION', 'CATEGORIE',
#        'EmailURL', 'DESCRIPTION_DU_POSTE', 'Poste', 'Date', 'Région',
#        'Offre_Link', 'SECTEUR', 'URL_DU_POSTE', 'Job Image', 'Source URL',
#        'NOMBRE_DE_POSTE_DE_TRAVAIL', 'Titre du Poste', 'Niveau Requis',
#        'Année d'Expérience Requise', 'Lieu du Travail', 'Date de Soumission',
#        'annee_min', 'annee_max'],
#       dtype='object')

# %%
df=result
df = df[['BRANCHE_D_ACTIVITE', 'TYPE_DE_CONTRAT_DU_POSTE', 'SPECIALITE', 'DIPLOME', 'EXPERIENCE_PROFESSIONNELLE',
         'LIEU_DU_POSTE_DE_TRAVAIL', 'DATE_DE_DEBUT_DE_L_OFFRE', 'DATE_D_EXPIRATION_DE_L_OFFRE', 'Description',
         'INTITULE_DU_POSTE', 'Sous_titre', 'Code', 'Date_DEdition', 'Date_limite', 'PAYS_DU_POSTE_DE_TRAVAIL',
         'URL', 'Unite_EXPERIENCE_PROFESSIONNELLE', 'Entreprise', 'Niveau', 'Experience_lettre', 'url',
         'Niveau de poste', 'Texte_fourni', 'Niveau d\'étude (diplome)', 'NOMBRE_DE_POSTES_A_POURVOIR',
         'RAISON_SOCIALE_DE_L_ENTREPRISE', 'VILLE_DU_POSTE_DE_TRAVAIL', 'DATE_DE_PUBLICATION', 'CATEGORIE', 'EmailURL',
         'DESCRIPTION_DU_POSTE', 'Poste', 'Date', 'Région', 'Offre_Link', 'SECTEUR', 'URL_DU_POSTE', 'Job Image',
         'Source URL', 'NOMBRE_DE_POSTE_DE_TRAVAIL', 'Titre du Poste', 'Niveau Requis', 'Année d\'Expérience Requise',
         'Lieu du Travail', 'Date de Soumission', 'annee_min', 'annee_max']]
df
# Out:
#                                       BRANCHE_D_ACTIVITE  \
# 0      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 1      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 2      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 3      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 4      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# ...                                                  ...
# 52517                                                NaN
# 52518                                                NaN
# 52519                                                NaN
# 52520                                                NaN
# 52521                                                NaN
#
#       TYPE_DE_CONTRAT_DU_POSTE    SPECIALITE DIPLOME  \
# 0                       Emploi  Informatique   BAC+5
# 1                       Emploi  Informatique   BAC+5
# 2                       Emploi  Informatique   BAC+5
# 3                       Emploi  Informatique   BAC+5
# 4                       Emploi  Informatique   BAC+5
# ...                        ...           ...     ...
# 52517                      NaN           NaN     NaN
# 52518                      NaN           NaN     NaN
# 52519                      NaN           NaN     NaN
# 52520                      NaN           NaN     NaN
# 52521                      NaN           NaN     NaN
#
#        EXPERIENCE_PROFESSIONNELLE LIEU_DU_POSTE_DE_TRAVAIL  \
# 0                             5.0            Côte d'Ivoire
# 1                             5.0            Côte d'Ivoire
# 2                             5.0            Côte d'Ivoire
# 3                             5.0            Côte d'Ivoire
# 4                             5.0            Côte d'Ivoire
# ...                           ...                      ...
# 52517                         NaN                      NaN
# 52518                         NaN             Burkina-Faso
# 52519                         NaN          Cotonou - Bénin
# 52520                         NaN                   Guinée
# 52521                         NaN                      NaN
#
#       DATE_DE_DEBUT_DE_L_OFFRE DATE_D_EXPIRATION_DE_L_OFFRE  \
# 0                   08/04/2024                   30/04/2024
# 1                   08/04/2024                   30/04/2024
# 2                   08/04/2024                   30/04/2024
# 3                   08/04/2024                   30/04/2024
# 4                   08/04/2024                   30/04/2024
# ...                        ...                          ...
# 52517          16 Janvier 2022                          NaN
# 52518          17 Janvier 2022                          NaN
# 52519          17 Janvier 2022                          NaN
# 52520          17 Janvier 2022                          NaN
# 52521          17 Janvier 2022                          NaN
#
#                                              Description  \
# 0      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
# 1      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
# 2      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
# 3      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
# 4      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...
# ...                                                  ...
# 52517                                                NaN
# 52518                                                NaN
# 52519                                                NaN
# 52520                                                NaN
# 52521                                                NaN
#
#                                        INTITULE_DU_POSTE  ...  \
# 0      EXPERT DEVELOPPEMENT LOCAL - PLANIFICATION DU ...  ...
# 1                                  SUPERVISEUR RÉGIONNAL  ...
# 2                                 10 COMMERCIAUX (STAGE)  ...
# 3                                     CONSULTANTS EN AGR  ...
# 4                              NAVIGATIONAL WATCH RATING  ...
# ...                                                  ...  ...
# 52517                       ACTED recrute pour ce poste   ...
# 52518  Médecins Sans Frontières MSF recrute pour ce p...  ...
# 52519                      FHI360 recrute pour ce poste   ...
# 52520           L’ONG Le GRET recrute pour ces 3 postes   ...
# 52521                 Le PNUD recrute pour ces 2 postes   ...
#
#                                                Job Image  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 52517  https://yop.l-frii.com/wp-content/uploads/2022...
# 52518  https://yop.l-frii.com/wp-content/uploads/2022...
# 52519  https://yop.l-frii.com/wp-content/uploads/2022...
# 52520  https://yop.l-frii.com/wp-content/uploads/2021...
# 52521  https://yop.l-frii.com/wp-content/uploads/2022...
#
#                                          Source URL  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 52517  https://yop.l-frii.com/offres-demplois/3275/
# 52518  https://yop.l-frii.com/offres-demplois/3275/
# 52519  https://yop.l-frii.com/offres-demplois/3275/
# 52520  https://yop.l-frii.com/offres-demplois/3275/
# 52521  https://yop.l-frii.com/offres-demplois/3275/
#
#       NOMBRE_DE_POSTE_DE_TRAVAIL       Titre du Poste  \
# 0                            NaN                  NaN
# 1                            NaN                  NaN
# 2                            NaN                  NaN
# 3                            NaN                  NaN
# 4                            NaN                  NaN
# ...                          ...                  ...
# 52517                        NaN  2023 © L-FRII MEDIA
# 52518                        NaN  2023 © L-FRII MEDIA
# 52519                        NaN  2023 © L-FRII MEDIA
# 52520                        3.0  2023 © L-FRII MEDIA
# 52521                        2.0  2023 © L-FRII MEDIA
#
#                          Niveau Requis Année d'Expérience Requise  \
# 0                                  NaN                        NaN
# 1                                  NaN                        NaN
# 2                                  NaN                        NaN
# 3                                  NaN                        NaN
# 4                                  NaN                        NaN
# ...                                ...                        ...
# 52517                  Licence, Master                      5 ans
# 52518                         Doctorat                      2 ans
# 52519                          BAC + 3                      5 ans
# 52520  Diplôme universitaire supérieur                      3 ans
# 52521                              NaN                        NaN
#
#                  Lieu du Travail Date de Soumission annee_min annee_max
# 0                            NaN                NaN       NaN       NaN
# 1                            NaN                NaN       NaN       NaN
# 2                            NaN                NaN       NaN       NaN
# 3                            NaN                NaN       NaN       NaN
# 4                            NaN                NaN       NaN       NaN
# ...                          ...                ...       ...       ...
# 52517                        NaN                NaN         5         5
# 52518  Burkina-Faso, Mali, Niger         07/02/2022         2         2
# 52519            Cotonou - Bénin         07/02/2022         5         5
# 52520                     Guinée         30/01/2022         3         3
# 52521                        NaN         31/01/2022       NaN       NaN
#
# [52522 rows x 47 columns]

# %%
df['Niveau'].unique() affiche array([nan, 'Manager / Responsable département', 'Débutant / Junior',
       "Responsable d'équipe", 'Confirmé / Expérimenté',
       'Stagiaire / Etudiant', 'Cadre dirigeant', 'Jeune diplômé'],
      dtype=object)
# Out:
# array([nan, 'Manager / Responsable département', 'Débutant / Junior',
#        "Responsable d'équipe", 'Confirmé / Expérimenté',
#        'Stagiaire / Etudiant', 'Cadre dirigeant', 'Jeune diplômé'],
#       dtype=object)

# %%
df['Niveau'] = df['Niveau'].fillna('').astype(str)
# Out:
# C:\Users\ngora\AppData\Local\Temp\ipykernel_25660\3566196651.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from plotly.io import write_html
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.express as px

# Charger les données (assurez-vous d'avoir préalablement importé les bibliothèques nécessaires et défini df)
# df = pd.read_csv("votre_fichier.csv")  # Remplacez "votre_fichier.csv" par votre fichier de données

# Initialiser l'application Dash avec les styles CSS
external_stylesheets = ['https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css']
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

# Définir la mise en page du tableau de bord
app.layout = html.Div(children=[
    html.H1(children='Tableau de Bord des Offres d\'Emploi', className='text-center mb-4', style={'color': 'green'}),

    # Filtres interactifs
    html.Div([
        html.Div([
            html.Label('Filtrer par Secteur d\'activité', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-secteur-activite',
                options=[{'label': 'Tout sélectionner', 'value': 'all'}] + [{'label': secteur, 'value': secteur} for secteur in df["BRANCHE_D_ACTIVITE"].unique()],
                value='all',
                className='form-control'
            ),
        ], className='col-md-4'),

        html.Div([
            html.Label('Filtrer par Type de contrat', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-type-contrat',
                options=[{'label': 'Tout sélectionner', 'value': 'all'}] + [{'label': contrat, 'value': contrat} for contrat in df["TYPE_DE_CONTRAT_DU_POSTE"].unique()],
                value='all',
                className='form-control'
            ),
        ], className='col-md-4'),

        html.Div([
            html.Label('Filtrer par Niveau d\'expérience', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-niveau-experience',
                options=[{'label': str(level), 'value': str(level)} for level in sorted(set(df['Niveau']))],
                value='all',
                className='form-control'
            ),
            
        ], className='col-md-4'),

        html.Button('Réinitialiser les filtres', id='bouton-reset', n_clicks=0, style={'background-color': 'green'})
    ], style={'display': 'flex', 'background-color': 'green'}),

    # Graphiques
    html.Div([
        dcc.Graph(id='graph-offres-par-secteur-activite', className='col-md-4'),
        dcc.Graph(id='graph-offres-par-type-contrat', className='col-md-4'),
        dcc.Graph(id='graph-offres-par-niveau-experience', className='col-md-4'),
    ], className='row', style={'background-color': 'white'})
])

# Callback pour mettre à jour les graphiques en fonction des filtres sélectionnés
@app.callback(
    [Output('graph-offres-par-secteur-activite', 'figure'),
     Output('graph-offres-par-type-contrat', 'figure'),
     Output('graph-offres-par-niveau-experience', 'figure')],
    [Input('filtre-secteur-activite', 'value'),
     Input('filtre-type-contrat', 'value'),
     Input('filtre-niveau-experience', 'value')]
)
def update_graphs(secteur_activite, type_contrat, niveau_experience):
    # Filtrer les données en fonction des sélections
    filtered_df = df.copy()
    if secteur_activite and secteur_activite != 'all':
        filtered_df = filtered_df[filtered_df['BRANCHE_D_ACTIVITE'] == secteur_activite]
    if type_contrat and type_contrat != 'all':
        filtered_df = filtered_df[filtered_df['TYPE_DE_CONTRAT_DU_POSTE'] == type_contrat]
    if niveau_experience and niveau_experience != 'all':
        filtered_df = filtered_df[filtered_df['Niveau'] == niveau_experience]

    # Créer les graphiques mis à jour
    fig_offres_par_secteur_activite = px.bar(filtered_df, x='BRANCHE_D_ACTIVITE', title="Nombre d'offres par secteur d'activité",
                                             color_discrete_sequence=['orange'])
    fig_offres_par_type_contrat = px.bar(filtered_df, x='TYPE_DE_CONTRAT_DU_POSTE', title="Nombre d'offres par type de contrat",
                                         color_discrete_sequence=['orange'])
    fig_offres_par_niveau_experience = px.bar(filtered_df, x='Niveau', title="Nombre d'offres par niveau d'expérience",
                                              color_discrete_sequence=['orange'])

    return fig_offres_par_secteur_activite, fig_offres_par_type_contrat, fig_offres_par_niveau_experience

if __name__ == '__main__':
    app.run_server(debug=True, port=8058)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8058/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from plotly.io import write_html
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.express as px

# Charger les données (assurez-vous d'avoir préalablement importé les bibliothèques nécessaires et défini df_offers)
# df_offers = pd.read_csv("votre_fichier.csv")  # Remplacez "votre_fichier.csv" par votre fichier de données

# Réorganiser les colonnes selon vos besoins


# Définir une fonction pour attribuer des valeurs numériques à l'expérience
def experience_level(row):
    exp_mapping = {
        'Moins d’un an': 1, 'Sans expérience': 1, '1 à 2 ans': 1, '2 à 3 ans': 2, '3 à 4 ans': 3, '4 à 5 ans': 4,
        '3 à 5 ans': 4, '5 à 6 ans': 5, '6 à 7 ans': 6, '6 à 10 ans': 6, '7 à 8 ans': 7, '8 à 9 ans': 8,
        '9 à 10 ans': 9, 'Plus de 10 ans': 11
    }
    return exp_mapping.get(row['Experience_lettre'], 12)

# Appliquer la fonction pour créer une nouvelle colonne "Niveau_experience"
scrap_novojob['Niveau_experience'] = scrap_novojob.apply(experience_level, axis=1)

# Options pour les filtres
secteurs_activite_options = [{'label': 'Tout sélectionner', 'value': 'all'}] + [{'label': secteur, 'value': secteur} for secteur in scrap_novojob["BRANCHE_D_ACTIVITE"].unique()]
types_contrat_options = [{'label': 'Tout sélectionner', 'value': 'all'}] + [{'label': contrat, 'value': contrat} for contrat in scrap_novojob["TYPE_DE_CONTRAT_DU_POSTE"].unique() if pd.notna(contrat)]
niveaux_experience_options = [{'label': level, 'value': level} for level in sorted(set(scrap_novojob['Niveau']))]

# Palettes de couleurs
secteur_activite_palette = px.colors.qualitative.Pastel1
entreprise_palette = px.colors.qualitative.Set2
type_contrat_palette = px.colors.qualitative.Pastel2

# Initialiser l'application Dash avec les styles CSS
external_stylesheets = ['https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css']
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

# Définir la mise en page du tableau de bord
app.layout = html.Div(children=[
    html.H1(children='Tableau de Bord des Offres d\'Emploi', className='text-center mb-4', style={'color': 'green'}),

    # Filtres interactifs
    html.Div([
        html.Div([
            html.Label('Filtrer par Secteur d\'activité', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-secteur-activite',
                options=secteurs_activite_options,
                value='Tous les secteurs d\'activité',
                className='form-control'
            ),
        ], className='col-md-4'),

        html.Div([
            html.Label('Filtrer par Type de contrat', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-type-contrat',
                options=types_contrat_options,
                value='Tous les types de contrat',
                className='form-control'
            ),
        ], className='col-md-4'),

        html.Div([
            html.Label('Filtrer par Niveau d\'expérience', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-niveau-experience',
                options=niveaux_experience_options,
                value='Tous les niveaux d\'expérience',
                className='form-control'
            ),
        ], className='col-md-4'),

        html.Button('Réinitialiser les filtres', id='bouton-reset', n_clicks=0, style={'background-color': 'green'})
    ], style={'display': 'flex', 'background-color': 'green'}),

    # Graphiques
    html.Div([
        dcc.Graph(id='graph-secteur-activite', className='col-md-6'),
        dcc.Graph(id='graph-entreprise', className='col-md-6'),
        dcc.Graph(id='graph-type-contrat', className='col-md-6'),
        dcc.Graph(id='graph-part-entreprises-par-type', className='col-md-6'),
        dcc.Graph(id='graph-taille-moyenne-entreprises', className='col-md-6'),
        dcc.Graph(id='graph-part-entreprises-par-categorie', className='col-md-6'),
        
    ],className='row', style={'background-color': 'white'})
])

# Callback pour mettre à jour les graphiques en fonction des filtres
@app.callback(
    [Output('graph-secteur-activite', 'figure'),
     Output('graph-entreprise', 'figure'),
     Output('graph-type-contrat', 'figure'),
     Output('graph-part-entreprises-par-type', 'figure'),
     Output('graph-part-entreprises-par-categorie', 'figure'),
     Output('graph-taille-moyenne-entreprises', 'figure')],
    [Input('filtre-secteur-activite', 'value'),
     Input('filtre-type-contrat', 'value'),
     Input('filtre-niveau-experience', 'value'),
     Input('bouton-reset', 'n_clicks')]
)
def update_graphs(secteurs_activite, types_contrat, niveaux_experience, n_clicks_reset):
    # Filtrage du DataFrame en fonction des sélections
    df_filtered = df
    # Définir les filtres à appliquer
    filters = {
        'BRANCHE_D_ACTIVITE': secteurs_activite,
        'TYPE_DE_CONTRAT_DU_POSTE': types_contrat,
        'Niveau': niveaux_experience
    }

    # Appliquer les filtres
    for column, values in filters.items():
        if values and 'Tous' not in values:
            if isinstance(values, str):
                values = [values]  # Transformer en liste si c'est une chaîne de caractères unique
            df_filtered = df_filtered[df_filtered[column].isin(values)]

    # Graphique du nombre d'offres par secteur d'activité
    fig_secteur_activite = px.bar(df_filtered, x="BRANCHE_D_ACTIVITE", title="Nombre d'offres par secteur d'activité",
                                    color_discrete_sequence=['orange'])

    # Graphique du nombre d'offres par entreprise
    fig_entreprise = px.bar(df_filtered, x="Entreprise", title="Nombre d'offres par entreprise",
                            color_discrete_sequence=['orange'])

    # Graphique du type de contrat proposé
    fig_type_contrat = px.bar(df_filtered, x="TYPE_DE_CONTRAT_DU_POSTE", title="Type de contrat proposé",
                               color_discrete_sequence=['orange'])

    # Graphique pour la part des entreprises par type de contrat
    fig_part_entreprises_par_type = px.pie(df_filtered, names="TYPE_DE_CONTRAT_DU_POSTE",
                                           title="Part des entreprises par type de contrat", color_discrete_sequence=['orange'])

    # Graphique pour la part des entreprises par catégorie
    fig_part_entreprises_par_categorie = px.pie(df_filtered, names="Niveau de poste",
                                                title="Part des entreprises par catégorie", color_discrete_sequence=['orange'])

    # Graphique pour la taille moyenne des entreprises par catégorie
    fig_taille_moyenne_entreprises = px.bar(df_filtered, x="Niveau de poste", y="NOMBRE_DE_POSTES_A_POURVOIR",
                                             title="Taille moyenne des entreprises par catégorie", color_discrete_sequence=['orange'])

    return fig_secteur_activite, fig_entreprise, fig_type_contrat, fig_part_entreprises_par_type, fig_part_entreprises_par_categorie, fig_taille_moyenne_entreprises

if __name__ == '__main__':
    app.run_server(debug=True, port=8058)

    # Récupérer les figures après l'exécution de l'application
    fig_secteur_activite, fig_entreprise, fig_type_contrat, fig_part_entreprises_par_type, fig_part_entreprises_par_categorie, fig_taille_moyenne_entreprises = update_graphs(
        None, None, None, None)

    # Sauvegarder les graphiques au format HTML
    write_html(fig_secteur_activite, 'graph_secteur_activite.html')
    write_html(fig_entreprise, 'graph_entreprise.html')
    write_html(fig_type_contrat, 'graph_type_contrat.html')
    write_html(fig_part_entreprises_par_type, 'graph_part_entreprises_par_type.html')
    write_html(fig_part_entreprises_par_categorie, 'graph_part_entreprises_par_categorie.html')
    write_html(fig_taille_moyenne_entreprises, 'graph_taille_moyenne_entreprises.html')
# Out:
# C:\Users\ngora\AppData\Local\Temp\ipykernel_25660\2445481088.py:25: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8058/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from plotly.io import write_html
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.express as px

# Charger les données (assurez-vous d'avoir préalablement importé les bibliothèques nécessaires et défini df_offers)
# df_offers = pd.read_csv("votre_fichier.csv")  # Remplacez "votre_fichier.csv" par votre fichier de données

# Réorganiser les colonnes selon vos besoins
scrap_novojob=Data_Scrapping_df_novojob_09042024
scrap_novojob = scrap_novojob[[
    'INTITULE_DU_POSTE', 'Entreprise', 'PAYS_DU_POSTE_DE_TRAVAIL', 'DATE_DE_DEBUT_DE_L_OFFRE', 'Niveau', 'Experience_lettre',
    'url', "SITE_WEB_DE_L_ENTREPRISE", "RAISON_SOCIALE_DE_L_ENTREPRISE", "BRANCHE_D_ACTIVITE", "LIEU_DU_POSTE_DE_TRAVAIL",
    "DATE_D_EXPIRATION_DE_L_OFFRE", "NOMBRE_DE_POSTES_A_POURVOIR", "Niveau de poste", "Niveau d'étude (diplome)", "TYPE_DE_CONTRAT_DU_POSTE",
    "Texte_fourni", "VILLE_DU_POSTE_DE_TRAVAIL"
]]

# Définir une fonction pour attribuer des valeurs numériques à l'expérience
def experience_level(row):
    exp_mapping = {
        'Moins d’un an': 1, 'Sans expérience': 1, '1 à 2 ans': 1, '2 à 3 ans': 2, '3 à 4 ans': 3, '4 à 5 ans': 4,
        '3 à 5 ans': 4, '5 à 6 ans': 5, '6 à 7 ans': 6, '6 à 10 ans': 6, '7 à 8 ans': 7, '8 à 9 ans': 8,
        '9 à 10 ans': 9, 'Plus de 10 ans': 11
    }
    return exp_mapping.get(row['Experience_lettre'], 12)

# Appliquer la fonction pour créer une nouvelle colonne "Niveau_experience"
scrap_novojob['Niveau_experience'] = scrap_novojob.apply(experience_level, axis=1)

# Options pour les filtres
secteurs_activite_options = [{'label': 'Tout sélectionner', 'value': 'all'}] + [{'label': secteur, 'value': secteur} for secteur in scrap_novojob["BRANCHE_D_ACTIVITE"].unique()]
types_contrat_options = [{'label': 'Tout sélectionner', 'value': 'all'}] + [{'label': contrat, 'value': contrat} for contrat in scrap_novojob["TYPE_DE_CONTRAT_DU_POSTE"].unique() if pd.notna(contrat)]
niveaux_experience_options = [{'label': level, 'value': level} for level in sorted(set(scrap_novojob['Niveau']))]

# Palettes de couleurs
secteur_activite_palette = px.colors.qualitative.Pastel1
entreprise_palette = px.colors.qualitative.Set2
type_contrat_palette = px.colors.qualitative.Pastel2

# Initialiser l'application Dash avec les styles CSS
external_stylesheets = ['https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css']
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

# Définir la mise en page du tableau de bord
app.layout = html.Div(children=[
    html.H1(children='Tableau de Bord des Offres d\'Emploi', className='text-center mb-4', style={'color': 'green'}),

    # Filtres interactifs
    html.Div([
        html.Div([
            html.Label('Filtrer par Secteur d\'activité', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-secteur-activite',
                options=secteurs_activite_options,
                value='Tous les secteurs d\'activité',
                className='form-control'
            ),
        ], className='col-md-4'),

        html.Div([
            html.Label('Filtrer par Type de contrat', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-type-contrat',
                options=types_contrat_options,
                value='Tous les types de contrat',
                className='form-control'
            ),
        ], className='col-md-4'),

        html.Div([
            html.Label('Filtrer par Niveau d\'expérience', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-niveau-experience',
                options=niveaux_experience_options,
                value='Tous les niveaux d\'expérience',
                className='form-control'
            ),
        ], className='col-md-4'),

        html.Button('Réinitialiser les filtres', id='bouton-reset', n_clicks=0, style={'background-color': 'green'})
    ], style={'display': 'flex', 'background-color': 'green'}),

    # Graphiques
    html.Div([
        dcc.Graph(id='graph-secteur-activite', className='col-md-6'),
        dcc.Graph(id='graph-entreprise', className='col-md-6'),
        dcc.Graph(id='graph-type-contrat', className='col-md-6'),
        dcc.Graph(id='graph-part-entreprises-par-type', className='col-md-6'),
        dcc.Graph(id='graph-taille-moyenne-entreprises', className='col-md-6'),
        dcc.Graph(id='graph-part-entreprises-par-categorie', className='col-md-6'),
        
    ],className='row', style={'background-color': 'white'})
])

# Callback pour mettre à jour les graphiques en fonction des filtres
@app.callback(
    [Output('graph-secteur-activite', 'figure'),
     Output('graph-entreprise', 'figure'),
     Output('graph-type-contrat', 'figure'),
     Output('graph-part-entreprises-par-type', 'figure'),
     Output('graph-part-entreprises-par-categorie', 'figure'),
     Output('graph-taille-moyenne-entreprises', 'figure')],
    [Input('filtre-secteur-activite', 'value'),
     Input('filtre-type-contrat', 'value'),
     Input('filtre-niveau-experience', 'value'),
     Input('bouton-reset', 'n_clicks')]
)
def update_graphs(secteurs_activite, types_contrat, niveaux_experience, n_clicks_reset):
    # Filtrage du DataFrame en fonction des sélections
    df_filtered = scrap_novojob
    # Définir les filtres à appliquer
    filters = {
        'BRANCHE_D_ACTIVITE': secteurs_activite,
        'TYPE_DE_CONTRAT_DU_POSTE': types_contrat,
        'Niveau': niveaux_experience
    }

    # Appliquer les filtres
    for column, values in filters.items():
        if values and 'Tous' not in values:
            if isinstance(values, str):
                values = [values]  # Transformer en liste si c'est une chaîne de caractères unique
            df_filtered = df_filtered[df_filtered[column].isin(values)]

    # Graphique du nombre d'offres par secteur d'activité
    fig_secteur_activite = px.bar(df_filtered, x="BRANCHE_D_ACTIVITE", title="Nombre d'offres par secteur d'activité",
                                    color_discrete_sequence=['orange'])

    # Graphique du nombre d'offres par entreprise
    fig_entreprise = px.bar(df_filtered, x="Entreprise", title="Nombre d'offres par entreprise",
                            color_discrete_sequence=['orange'])

    # Graphique du type de contrat proposé
    fig_type_contrat = px.bar(df_filtered, x="TYPE_DE_CONTRAT_DU_POSTE", title="Type de contrat proposé",
                               color_discrete_sequence=['orange'])

    # Graphique pour la part des entreprises par type de contrat
    fig_part_entreprises_par_type = px.pie(df_filtered, names="TYPE_DE_CONTRAT_DU_POSTE",
                                           title="Part des entreprises par type de contrat", color_discrete_sequence=['orange'])

    # Graphique pour la part des entreprises par catégorie
    fig_part_entreprises_par_categorie = px.pie(df_filtered, names="Niveau de poste",
                                                title="Part des entreprises par catégorie", color_discrete_sequence=['orange'])

    # Graphique pour la taille moyenne des entreprises par catégorie
    fig_taille_moyenne_entreprises = px.bar(df_filtered, x="Niveau de poste", y="NOMBRE_DE_POSTES_A_POURVOIR",
                                             title="Taille moyenne des entreprises par catégorie", color_discrete_sequence=['orange'])

    return fig_secteur_activite, fig_entreprise, fig_type_contrat, fig_part_entreprises_par_type, fig_part_entreprises_par_categorie, fig_taille_moyenne_entreprises

if __name__ == '__main__':
    app.run_server(debug=True, port=8058)

    # Récupérer les figures après l'exécution de l'application
    fig_secteur_activite, fig_entreprise, fig_type_contrat, fig_part_entreprises_par_type, fig_part_entreprises_par_categorie, fig_taille_moyenne_entreprises = update_graphs(
        None, None, None, None)

    # Sauvegarder les graphiques au format HTML
    write_html(fig_secteur_activite, 'graph_secteur_activite.html')
    write_html(fig_entreprise, 'graph_entreprise.html')
    write_html(fig_type_contrat, 'graph_type_contrat.html')
    write_html(fig_part_entreprises_par_type, 'graph_part_entreprises_par_type.html')
    write_html(fig_part_entreprises_par_categorie, 'graph_part_entreprises_par_categorie.html')
    write_html(fig_taille_moyenne_entreprises, 'graph_taille_moyenne_entreprises.html')
# Out:
# C:\Users\ngora\AppData\Local\Temp\ipykernel_25660\2862504128.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8058/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from plotly.io import write_html
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.express as px

# Charger les données (assurez-vous d'avoir préalablement importé les bibliothèques nécessaires et défini df_offers)
# df_offers = pd.read_csv("votre_fichier.csv")  # Remplacez "votre_fichier.csv" par votre fichier de données

# Réorganiser les colonnes selon vos besoins


# Définir une fonction pour attribuer des valeurs numériques à l'expérience
def experience_level(row):
    exp_mapping = {
        'Moins d’un an': 1, 'Sans expérience': 1, '1 à 2 ans': 1, '2 à 3 ans': 2, '3 à 4 ans': 3, '4 à 5 ans': 4,
        '3 à 5 ans': 4, '5 à 6 ans': 5, '6 à 7 ans': 6, '6 à 10 ans': 6, '7 à 8 ans': 7, '8 à 9 ans': 8,
        '9 à 10 ans': 9, 'Plus de 10 ans': 11
    }
    return exp_mapping.get(row['Experience_lettre'], 12)

# Appliquer la fonction pour créer une nouvelle colonne "Niveau_experience"
df['Niveau_experience'] = df.apply(experience_level, axis=1)

# Options pour les filtres
# Filtrer les options pour exclure celles avec une étiquette nulle
# Options pour les filtres
secteurs_activite_options = [{'label': 'Tout sélectionner', 'value': 'all'}] + [{'label': secteur, 'value': secteur} for secteur in df["BRANCHE_D_ACTIVITE"].unique() if pd.notna(secteur)]

types_contrat_options = [{'label': 'Tout sélectionner', 'value': 'all'}] + [{'label': contrat, 'value': contrat} for contrat in df["TYPE_DE_CONTRAT_DU_POSTE"].unique() if pd.notna(contrat)]
niveaux_experience_options = [{'label': level, 'value': level} for level in sorted(set(df['Niveau']))]

# Palettes de couleurs
secteur_activite_palette = px.colors.qualitative.Pastel1
entreprise_palette = px.colors.qualitative.Set2
type_contrat_palette = px.colors.qualitative.Pastel2

# Initialiser l'application Dash avec les styles CSS
external_stylesheets = ['https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css']
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

# Définir la mise en page du tableau de bord
app.layout = html.Div(children=[
    html.H1(children='Tableau de Bord des Offres d\'Emploi', className='text-center mb-4', style={'color': 'green'}),

    # Filtres interactifs
    html.Div([
        html.Div([
            html.Label('Filtrer par Secteur d\'activité', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-secteur-activite',
                options=secteurs_activite_options,
                value='Tous les secteurs d\'activité',
                className='form-control'
            ),
        ], className='col-md-4'),

        html.Div([
            html.Label('Filtrer par Type de contrat', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-type-contrat',
                options=types_contrat_options,
                value='Tous les types de contrat',
                className='form-control'
            ),
        ], className='col-md-4'),

        html.Div([
            html.Label('Filtrer par Niveau d\'expérience', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-niveau-experience',
                options=niveaux_experience_options,
                value='Tous les niveaux d\'expérience',
                className='form-control'
            ),
        ], className='col-md-4'),

        html.Button('Réinitialiser les filtres', id='bouton-reset', n_clicks=0, style={'background-color': 'green'})
    ], style={'display': 'flex', 'background-color': 'green'}),

    # Graphiques
    html.Div([
        dcc.Graph(id='graph-secteur-activite', className='col-md-6'),
        dcc.Graph(id='graph-entreprise', className='col-md-6'),
        dcc.Graph(id='graph-type-contrat', className='col-md-6'),
        dcc.Graph(id='graph-part-entreprises-par-type', className='col-md-6'),
        dcc.Graph(id='graph-taille-moyenne-entreprises', className='col-md-6'),
        dcc.Graph(id='graph-part-entreprises-par-categorie', className='col-md-6'),
        
    ],className='row', style={'background-color': 'white'})
])

# Callback pour mettre à jour les graphiques en fonction des filtres
@app.callback(
    [Output('graph-secteur-activite', 'figure'),
     Output('graph-entreprise', 'figure'),
     Output('graph-type-contrat', 'figure'),
     Output('graph-part-entreprises-par-type', 'figure'),
     Output('graph-part-entreprises-par-categorie', 'figure'),
     Output('graph-taille-moyenne-entreprises', 'figure')],
    [Input('filtre-secteur-activite', 'value'),
     Input('filtre-type-contrat', 'value'),
     Input('filtre-niveau-experience', 'value'),
     Input('bouton-reset', 'n_clicks')]
)
def update_graphs(secteurs_activite, types_contrat, niveaux_experience, n_clicks_reset):
    # Filtrage du DataFrame en fonction des sélections
    df_filtered = df
    # Définir les filtres à appliquer
    filters = {
        'BRANCHE_D_ACTIVITE': secteurs_activite,
        'TYPE_DE_CONTRAT_DU_POSTE': types_contrat,
        'Niveau': niveaux_experience
    }

    # Appliquer les filtres
    for column, values in filters.items():
        if values and 'Tous' not in values:
            if isinstance(values, str):
                values = [values]  # Transformer en liste si c'est une chaîne de caractères unique
            df_filtered = df_filtered[df_filtered[column].isin(values)]

    # Graphique du nombre d'offres par secteur d'activité
    fig_secteur_activite = px.bar(df_filtered, x="BRANCHE_D_ACTIVITE", title="Nombre d'offres par secteur d'activité",
                                    color_discrete_sequence=['orange'])

    # Graphique du nombre d'offres par entreprise
    fig_entreprise = px.bar(df_filtered, x="Entreprise", title="Nombre d'offres par entreprise",
                            color_discrete_sequence=['orange'])

    # Graphique du type de contrat proposé
    fig_type_contrat = px.bar(df_filtered, x="TYPE_DE_CONTRAT_DU_POSTE", title="Type de contrat proposé",
                               color_discrete_sequence=['orange'])

    # Graphique pour la part des entreprises par type de contrat
    fig_part_entreprises_par_type = px.pie(df_filtered, names="TYPE_DE_CONTRAT_DU_POSTE",
                                           title="Part des entreprises par type de contrat", color_discrete_sequence=['orange'])

    # Graphique pour la part des entreprises par catégorie
    fig_part_entreprises_par_categorie = px.pie(df_filtered, names="Niveau de poste",
                                                title="Part des entreprises par catégorie", color_discrete_sequence=['orange'])

    # Graphique pour la taille moyenne des entreprises par catégorie
    fig_taille_moyenne_entreprises = px.bar(df_filtered, x="Niveau de poste", y="NOMBRE_DE_POSTES_A_POURVOIR",
                                             title="Taille moyenne des entreprises par catégorie", color_discrete_sequence=['orange'])

    return fig_secteur_activite, fig_entreprise, fig_type_contrat, fig_part_entreprises_par_type, fig_part_entreprises_par_categorie, fig_taille_moyenne_entreprises

if __name__ == '__main__':
    app.run_server(debug=True, port=8058)

    # Récupérer les figures après l'exécution de l'application
    fig_secteur_activite, fig_entreprise, fig_type_contrat, fig_part_entreprises_par_type, fig_part_entreprises_par_categorie, fig_taille_moyenne_entreprises = update_graphs(
        None, None, None, None)

    # Sauvegarder les graphiques au format HTML
    write_html(fig_secteur_activite, 'graph_secteur_activite.html')
    write_html(fig_entreprise, 'graph_entreprise.html')
    write_html(fig_type_contrat, 'graph_type_contrat.html')
    write_html(fig_part_entreprises_par_type, 'graph_part_entreprises_par_type.html')
    write_html(fig_part_entreprises_par_categorie, 'graph_part_entreprises_par_categorie.html')
    write_html(fig_taille_moyenne_entreprises, 'graph_taille_moyenne_entreprises.html')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8058/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#Data_Scrapping_df_educarriere_08042024 = pd.read_excel("Data_Scrapping_df_educarriere_08042024.xlsx")

# %%
Data_Scrapping_df_novojob_08042024 = pd.read_excel("Data_Scrapping_df_novojob_08042024.xlsx")

# %%
Data_Scrapping_df_projobivoire_08042024 = pd.read_excel("Data_Scrapping_df_projobivoire_08042024.xlsx")

# %%
Data_Scrapping_df_talent_ci_08042024 = pd.read_excel("Data_Scrapping_df_talent_ci_08042024.xlsx")

# %%
#Data_Scrapping_emploi_df_08042024 = pd.read_excel("Data_Scrapping_emploi_df_08042024.xlsx")

# %%
Data_Scrapping_mondiale_df_08042024 = pd.read_excel("Data_Scrapping_mondiale_df_08042024.xlsx")

# %%
#Data_Scrapping_yop_l_frii_total_08042024 = pd.read_excel("Data_Scrapping_yop_l_frii_total_08042024.xlsx")

# %%
# Concaténer les DataFrames
frames1 = [
          Data_Scrapping_df_novojob_08042024, 
          Data_Scrapping_df_projobivoire_08042024, 
          Data_Scrapping_df_talent_ci_08042024, 
           
          Data_Scrapping_mondiale_df_08042024, 
          ]

# Concaténer les DataFrames en un seul
result1 = pd.concat(frames1, ignore_index=True)

# Afficher le DataFrame résultant
result1
# Out:
#                           INTITULE_DU_POSTE Entreprise  \
# 0      Gestionnaire des Ressources Humaines        NaN
# 1      Gestionnaire des Ressources Humaines        NaN
# 2      Gestionnaire des Ressources Humaines        NaN
# 3      Gestionnaire des Ressources Humaines        NaN
# 4      Gestionnaire des Ressources Humaines        NaN
# ...                                     ...        ...
# 10257                                Driver        NaN
# 10258                                Driver        NaN
# 10259                        E T Consultant        NaN
# 10260                        E T Consultant        NaN
# 10261                        E T Consultant        NaN
#
#       PAYS_DU_POSTE_DE_TRAVAIL DATE_DE_DEBUT_DE_L_OFFRE  \
# 0                Côte d'ivoire                  24 Mars
# 1                Côte d'ivoire                  24 Mars
# 2                Côte d'ivoire                  24 Mars
# 3                Côte d'ivoire                  24 Mars
# 4                Côte d'ivoire                  24 Mars
# ...                        ...                      ...
# 10257                      NaN                      NaN
# 10258                      NaN                      NaN
# 10259                      NaN                      NaN
# 10260                      NaN                      NaN
# 10261                      NaN                      NaN
#
#                                   Niveau Experience_lettre  \
# 0      Manager / Responsable département        6 à 10 ans
# 1      Manager / Responsable département        6 à 10 ans
# 2      Manager / Responsable département        6 à 10 ans
# 3      Manager / Responsable département        6 à 10 ans
# 4      Manager / Responsable département        6 à 10 ans
# ...                                  ...               ...
# 10257                                NaN               NaN
# 10258                                NaN               NaN
# 10259                                NaN               NaN
# 10260                                NaN               NaN
# 10261                                NaN               NaN
#
#                                                      url  \
# 0      https://www.novojob.com/cote-d-ivoire/offres-d...
# 1      https://www.novojob.com/cote-d-ivoire/offres-d...
# 2      https://www.novojob.com/cote-d-ivoire/offres-d...
# 3      https://www.novojob.com/cote-d-ivoire/offres-d...
# 4      https://www.novojob.com/cote-d-ivoire/offres-d...
# ...                                                  ...
# 10257                                                NaN
# 10258                                                NaN
# 10259                                                NaN
# 10260                                                NaN
# 10261                                                NaN
#
#                                 SITE_WEB_DE_L_ENTREPRISE  \
# 0      https://www.novojob.com/cote-d-ivoire/offres-d...
# 1      https://www.novojob.com/cote-d-ivoire/offres-d...
# 2      https://www.novojob.com/cote-d-ivoire/offres-d...
# 3      https://www.novojob.com/cote-d-ivoire/offres-d...
# 4      https://www.novojob.com/cote-d-ivoire/offres-d...
# ...                                                  ...
# 10257                                                NaN
# 10258                                                NaN
# 10259                                                NaN
# 10260                                                NaN
# 10261                                                NaN
#
#            LIEU_DU_POSTE_DE_TRAVAIL DATE_D_EXPIRATION_DE_L_OFFRE  ...  \
# 0            Abidjan, Côte d'ivoire                      22 Juin  ...
# 1            Abidjan, Côte d'ivoire                      22 Juin  ...
# 2            Abidjan, Côte d'ivoire                      22 Juin  ...
# 3            Abidjan, Côte d'ivoire                      22 Juin  ...
# 4            Abidjan, Côte d'ivoire                      22 Juin  ...
# ...                             ...                          ...  ...
# 10257                  Kyiv,Ukraine                    4/15/2024  ...
# 10258            Panama City,Panama                    4/17/2024  ...
# 10259              Brussels,Belgium                     4/9/2024  ...
# 10260  Washington, DC,United States                    4/15/2024  ...
# 10261  Washington, DC,United States                     4/9/2024  ...
#
#       Niveau d'étude (diplome) NOMBRE_DE_POSTES_A_POURVOIR  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ...                        ...                         ...
# 10257                      NaN                         NaN
# 10258                      NaN                         NaN
# 10259                      NaN                         NaN
# 10260                      NaN                         NaN
# 10261                      NaN                         NaN
#
#       TYPE_DE_CONTRAT_DU_POSTE RAISON_SOCIALE_DE_L_ENTREPRISE  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
# ...                        ...                            ...
# 10257                      NaN                            NaN
# 10258                      NaN                            NaN
# 10259                      NaN                            NaN
# 10260                      NaN                            NaN
# 10261                      NaN                            NaN
#
#        VILLE_DU_POSTE_DE_TRAVAIL DATE_DE_PUBLICATION CATEGORIE EmailURL  \
# 0                        Abidjan                 NaN       NaN      NaN
# 1                        Abidjan                 NaN       NaN      NaN
# 2                        Abidjan                 NaN       NaN      NaN
# 3                        Abidjan                 NaN       NaN      NaN
# 4                        Abidjan                 NaN       NaN      NaN
# ...                          ...                 ...       ...      ...
# 10257                        NaN                 NaN       NaN      NaN
# 10258                        NaN                 NaN       NaN      NaN
# 10259                        NaN                 NaN       NaN      NaN
# 10260                        NaN                 NaN       NaN      NaN
# 10261                        NaN                 NaN       NaN      NaN
#
#       DESCRIPTION_DU_POSTE                        SECTEUR
# 0                      NaN                            NaN
# 1                      NaN                            NaN
# 2                      NaN                            NaN
# 3                      NaN                            NaN
# 4                      NaN                            NaN
# ...                    ...                            ...
# 10257                  NaN  Administration/Office Support
# 10258                  NaN  Administration/Office Support
# 10259                  NaN                 Transportation
# 10260                  NaN    Health/Nutrition/Population
# 10261                  NaN                      Economics
#
# [10262 rows x 23 columns]

# %%
result_2 = pd.concat([result, result1], ignore_index=True)

# Afficher le DataFrame résultant


result_2
# Out:
#                                       BRANCHE_D_ACTIVITE  \
# 0      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 1      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 2      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 3      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 4      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# ...                                                  ...
# 62779                                                NaN
# 62780                                                NaN
# 62781                                                NaN
# 62782                                                NaN
# 62783                                                NaN
#
#       TYPE_DE_CONTRAT_DU_POSTE    SPECIALITE DIPLOME  \
# 0                       Emploi  Informatique   BAC+5
# 1                       Emploi  Informatique   BAC+5
# 2                       Emploi  Informatique   BAC+5
# 3                       Emploi  Informatique   BAC+5
# 4                       Emploi  Informatique   BAC+5
# ...                        ...           ...     ...
# 62779                      NaN           NaN     NaN
# 62780                      NaN           NaN     NaN
# 62781                      NaN           NaN     NaN
# 62782                      NaN           NaN     NaN
# 62783                      NaN           NaN     NaN
#
#        EXPERIENCE_PROFESSIONNELLE      LIEU_DU_POSTE_DE_TRAVAIL  \
# 0                             5.0                 Côte d'Ivoire
# 1                             5.0                 Côte d'Ivoire
# 2                             5.0                 Côte d'Ivoire
# 3                             5.0                 Côte d'Ivoire
# 4                             5.0                 Côte d'Ivoire
# ...                           ...                           ...
# 62779                         NaN                  Kyiv,Ukraine
# 62780                         NaN            Panama City,Panama
# 62781                         NaN              Brussels,Belgium
# 62782                         NaN  Washington, DC,United States
# 62783                         NaN  Washington, DC,United States
#
#                                 SITE_WEB_DE_L_ENTREPRISE  \
# 0      https://emploi.educarriere.ci/offre-116075-exp...
# 1      https://emploi.educarriere.ci/offre-116075-exp...
# 2      https://emploi.educarriere.ci/offre-116075-exp...
# 3      https://emploi.educarriere.ci/offre-116075-exp...
# 4      https://emploi.educarriere.ci/offre-116075-exp...
# ...                                                  ...
# 62779                                                NaN
# 62780                                                NaN
# 62781                                                NaN
# 62782                                                NaN
# 62783                                                NaN
#
#       DATE_DE_DEBUT_DE_L_OFFRE DATE_D_EXPIRATION_DE_L_OFFRE  \
# 0                   08/04/2024                   30/04/2024
# 1                   08/04/2024                   30/04/2024
# 2                   08/04/2024                   30/04/2024
# 3                   08/04/2024                   30/04/2024
# 4                   08/04/2024                   30/04/2024
# ...                        ...                          ...
# 62779                      NaN                    4/15/2024
# 62780                      NaN                    4/17/2024
# 62781                      NaN                     4/9/2024
# 62782                      NaN                    4/15/2024
# 62783                      NaN                     4/9/2024
#
#                                              Description  ... Job Image  \
# 0      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...       NaN
# 1      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...       NaN
# 2      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...       NaN
# 3      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...       NaN
# 4      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...       NaN
# ...                                                  ...  ...       ...
# 62779                                                NaN  ...       NaN
# 62780                                                NaN  ...       NaN
# 62781                                                NaN  ...       NaN
# 62782                                                NaN  ...       NaN
# 62783                                                NaN  ...       NaN
#
#       Source URL  NOMBRE_DE_POSTE_DE_TRAVAIL Titre du Poste Niveau Requis  \
# 0            NaN                         NaN            NaN           NaN
# 1            NaN                         NaN            NaN           NaN
# 2            NaN                         NaN            NaN           NaN
# 3            NaN                         NaN            NaN           NaN
# 4            NaN                         NaN            NaN           NaN
# ...          ...                         ...            ...           ...
# 62779        NaN                         NaN            NaN           NaN
# 62780        NaN                         NaN            NaN           NaN
# 62781        NaN                         NaN            NaN           NaN
# 62782        NaN                         NaN            NaN           NaN
# 62783        NaN                         NaN            NaN           NaN
#
#       Année d'Expérience Requise Lieu du Travail Date de Soumission annee_min  \
# 0                            NaN             NaN                NaN       NaN
# 1                            NaN             NaN                NaN       NaN
# 2                            NaN             NaN                NaN       NaN
# 3                            NaN             NaN                NaN       NaN
# 4                            NaN             NaN                NaN       NaN
# ...                          ...             ...                ...       ...
# 62779                        NaN             NaN                NaN       NaN
# 62780                        NaN             NaN                NaN       NaN
# 62781                        NaN             NaN                NaN       NaN
# 62782                        NaN             NaN                NaN       NaN
# 62783                        NaN             NaN                NaN       NaN
#
#       annee_max
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 62779       NaN
# 62780       NaN
# 62781       NaN
# 62782       NaN
# 62783       NaN
#
# [62784 rows x 48 columns]

# %%
result_2 = result_2.drop_duplicates()
result_2.reset_index(drop=True, inplace=True)

result_2
# Out:
#                                       BRANCHE_D_ACTIVITE  \
# 0      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 1      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 2      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 3      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# 4      EXPERT(E) DÉVELOPPEUR DE SITE INTERNET INTERACTIF
# ...                                                  ...
# 61134                                                NaN
# 61135                                                NaN
# 61136                                                NaN
# 61137                                                NaN
# 61138                                                NaN
#
#       TYPE_DE_CONTRAT_DU_POSTE    SPECIALITE DIPLOME  \
# 0                       Emploi  Informatique   BAC+5
# 1                       Emploi  Informatique   BAC+5
# 2                       Emploi  Informatique   BAC+5
# 3                       Emploi  Informatique   BAC+5
# 4                       Emploi  Informatique   BAC+5
# ...                        ...           ...     ...
# 61134                      NaN           NaN     NaN
# 61135                      NaN           NaN     NaN
# 61136                      NaN           NaN     NaN
# 61137                      NaN           NaN     NaN
# 61138                      NaN           NaN     NaN
#
#        EXPERIENCE_PROFESSIONNELLE              LIEU_DU_POSTE_DE_TRAVAIL  \
# 0                             5.0                         Côte d'Ivoire
# 1                             5.0                         Côte d'Ivoire
# 2                             5.0                         Côte d'Ivoire
# 3                             5.0                         Côte d'Ivoire
# 4                             5.0                         Côte d'Ivoire
# ...                           ...                                   ...
# 61134                         NaN  Abidjan, Abidjan Autonomous District
# 61135                         NaN  Abidjan, Abidjan Autonomous District
# 61136                         NaN  Abidjan, Abidjan Autonomous District
# 61137                         NaN                         Nairobi,Kenya
# 61138                         NaN          Washington, DC,United States
#
#                                 SITE_WEB_DE_L_ENTREPRISE  \
# 0      https://emploi.educarriere.ci/offre-116075-exp...
# 1      https://emploi.educarriere.ci/offre-116075-exp...
# 2      https://emploi.educarriere.ci/offre-116075-exp...
# 3      https://emploi.educarriere.ci/offre-116075-exp...
# 4      https://emploi.educarriere.ci/offre-116075-exp...
# ...                                                  ...
# 61134  https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
# 61135  https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
# 61136  https://ci.talent.com/jobs?l=Abidjan%2C+Abidja...
# 61137                                                NaN
# 61138                                                NaN
#
#       DATE_DE_DEBUT_DE_L_OFFRE DATE_D_EXPIRATION_DE_L_OFFRE  \
# 0                   08/04/2024                   30/04/2024
# 1                   08/04/2024                   30/04/2024
# 2                   08/04/2024                   30/04/2024
# 3                   08/04/2024                   30/04/2024
# 4                   08/04/2024                   30/04/2024
# ...                        ...                          ...
# 61134                      NaN                          NaN
# 61135                      NaN                          NaN
# 61136                      NaN                          NaN
# 61137                      NaN                    4/12/2024
# 61138                      NaN                     4/9/2024
#
#                                              Description  ... Job Image  \
# 0      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...       NaN
# 1      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...       NaN
# 2      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...       NaN
# 3      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...       NaN
# 4      MDHoldingrecruteEXPERT(E) DÉVELOPPEUR DE SITE ...  ...       NaN
# ...                                                  ...  ...       ...
# 61134                                                NaN  ...       NaN
# 61135                                                NaN  ...       NaN
# 61136                                                NaN  ...       NaN
# 61137                                                NaN  ...       NaN
# 61138                                                NaN  ...       NaN
#
#       Source URL  NOMBRE_DE_POSTE_DE_TRAVAIL Titre du Poste Niveau Requis  \
# 0            NaN                         NaN            NaN           NaN
# 1            NaN                         NaN            NaN           NaN
# 2            NaN                         NaN            NaN           NaN
# 3            NaN                         NaN            NaN           NaN
# 4            NaN                         NaN            NaN           NaN
# ...          ...                         ...            ...           ...
# 61134        NaN                         NaN            NaN           NaN
# 61135        NaN                         NaN            NaN           NaN
# 61136        NaN                         NaN            NaN           NaN
# 61137        NaN                         NaN            NaN           NaN
# 61138        NaN                         NaN            NaN           NaN
#
#       Année d'Expérience Requise Lieu du Travail Date de Soumission annee_min  \
# 0                            NaN             NaN                NaN       NaN
# 1                            NaN             NaN                NaN       NaN
# 2                            NaN             NaN                NaN       NaN
# 3                            NaN             NaN                NaN       NaN
# 4                            NaN             NaN                NaN       NaN
# ...                          ...             ...                ...       ...
# 61134                        NaN             NaN                NaN       NaN
# 61135                        NaN             NaN                NaN       NaN
# 61136                        NaN             NaN                NaN       NaN
# 61137                        NaN             NaN                NaN       NaN
# 61138                        NaN             NaN                NaN       NaN
#
#       annee_max
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 61134       NaN
# 61135       NaN
# 61136       NaN
# 61137       NaN
# 61138       NaN
#
# [61139 rows x 48 columns]

# %%
from plotly.io import write_html
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.express as px

# Charger les données (assurez-vous d'avoir préalablement importé les bibliothèques nécessaires et défini df_offers)
# df_offers = pd.read_csv("votre_fichier.csv")  # Remplacez "votre_fichier.csv" par votre fichier de données

# Réorganiser les colonnes selon vos besoins


# Définir une fonction pour attribuer des valeurs numériques à l'expérience
def experience_level(row):
    exp_mapping = {
        'Moins d’un an': 1, 'Sans expérience': 1, '1 à 2 ans': 1, '2 à 3 ans': 2, '3 à 4 ans': 3, '4 à 5 ans': 4,
        '3 à 5 ans': 4, '5 à 6 ans': 5, '6 à 7 ans': 6, '6 à 10 ans': 6, '7 à 8 ans': 7, '8 à 9 ans': 8,
        '9 à 10 ans': 9, 'Plus de 10 ans': 11
    }
    return exp_mapping.get(row['Experience_lettre'], 12)

# Appliquer la fonction pour créer une nouvelle colonne "Niveau_experience"
df['Niveau_experience'] = df.apply(experience_level, axis=1)

# Options pour les filtres
# Filtrer les options pour exclure celles avec une étiquette nulle
# Options pour les filtres
secteurs_activite_options = [{'label': 'Tout sélectionner', 'value': 'all'}] + [{'label': secteur, 'value': secteur} for secteur in df["BRANCHE_D_ACTIVITE"].unique() if pd.notna(secteur)]

types_contrat_options = [{'label': 'Tout sélectionner', 'value': 'all'}] + [{'label': contrat, 'value': contrat} for contrat in df["TYPE_DE_CONTRAT_DU_POSTE"].unique() if pd.notna(contrat)]
niveaux_experience_options = [{'label': level, 'value': level} for level in sorted(set(df['Niveau']))]

# Palettes de couleurs
secteur_activite_palette = px.colors.qualitative.Pastel1
entreprise_palette = px.colors.qualitative.Set2
type_contrat_palette = px.colors.qualitative.Pastel2

# Initialiser l'application Dash avec les styles CSS
external_stylesheets = ['https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css']
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

# Définir la mise en page du tableau de bord
app.layout = html.Div(children=[
    html.H1(children='Tableau de Bord des Offres d\'Emploi', className='text-center mb-4', style={'color': 'green'}),

    # Filtres interactifs
    html.Div([
        html.Div([
            html.Label('Filtrer par Secteur d\'activité', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-secteur-activite',
                options=secteurs_activite_options,
                value='Tous les secteurs d\'activité',
                className='form-control'
            ),
        ], className='col-md-4'),

        html.Div([
            html.Label('Filtrer par Type de contrat', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-type-contrat',
                options=types_contrat_options,
                value='Tous les types de contrat',
                className='form-control'
            ),
        ], className='col-md-4'),

        html.Div([
            html.Label('Filtrer par Niveau d\'expérience', style={'color': 'white'}),
            dcc.Dropdown(
                id='filtre-niveau-experience',
                options=niveaux_experience_options,
                value='Tous les niveaux d\'expérience',
                className='form-control'
            ),
        ], className='col-md-4'),

        html.Button('Réinitialiser les filtres', id='bouton-reset', n_clicks=0, style={'background-color': 'green'})
    ], style={'display': 'flex', 'background-color': 'green'}),

    # Graphiques
    html.Div([
        dcc.Graph(id='graph-secteur-activite', className='col-md-6'),
        dcc.Graph(id='graph-entreprise', className='col-md-6'),
        dcc.Graph(id='graph-type-contrat', className='col-md-6'),
        dcc.Graph(id='graph-part-entreprises-par-type', className='col-md-6'),
        dcc.Graph(id='graph-taille-moyenne-entreprises', className='col-md-6'),
        dcc.Graph(id='graph-part-entreprises-par-categorie', className='col-md-6'),
        
    ],className='row', style={'background-color': 'white'})
])

# Callback pour mettre à jour les graphiques en fonction des filtres
@app.callback(
    [Output('graph-secteur-activite', 'figure'),
     Output('graph-entreprise', 'figure'),
     Output('graph-type-contrat', 'figure'),
     Output('graph-part-entreprises-par-type', 'figure'),
     Output('graph-part-entreprises-par-categorie', 'figure'),
     Output('graph-taille-moyenne-entreprises', 'figure')],
    [Input('filtre-secteur-activite', 'value'),
     Input('filtre-type-contrat', 'value'),
     Input('filtre-niveau-experience', 'value'),
     Input('bouton-reset', 'n_clicks')]
)
def update_graphs(secteurs_activite, types_contrat, niveaux_experience, n_clicks_reset):
    # Filtrage du DataFrame en fonction des sélections
    df_filtered = result_2
    # Définir les filtres à appliquer
    filters = {
        'BRANCHE_D_ACTIVITE': secteurs_activite,
        'TYPE_DE_CONTRAT_DU_POSTE': types_contrat,
        'Niveau': niveaux_experience
    }

    # Appliquer les filtres
    for column, values in filters.items():
        if values and 'Tous' not in values:
            if isinstance(values, str):
                values = [values]  # Transformer en liste si c'est une chaîne de caractères unique
            df_filtered = df_filtered[df_filtered[column].isin(values)]

    # Graphique du nombre d'offres par secteur d'activité
    fig_secteur_activite = px.bar(df_filtered, x="BRANCHE_D_ACTIVITE", title="Nombre d'offres par secteur d'activité",
                                    color_discrete_sequence=['orange'])

    # Graphique du nombre d'offres par entreprise
    fig_entreprise = px.bar(df_filtered, x="Entreprise", title="Nombre d'offres par entreprise",
                            color_discrete_sequence=['orange'])

    # Graphique du type de contrat proposé
    fig_type_contrat = px.bar(df_filtered, x="TYPE_DE_CONTRAT_DU_POSTE", title="Type de contrat proposé",
                               color_discrete_sequence=['orange'])

    # Graphique pour la part des entreprises par type de contrat
    fig_part_entreprises_par_type = px.pie(df_filtered, names="TYPE_DE_CONTRAT_DU_POSTE",
                                           title="Part des entreprises par type de contrat", color_discrete_sequence=['orange'])

    # Graphique pour la part des entreprises par catégorie
    fig_part_entreprises_par_categorie = px.pie(df_filtered, names="Niveau de poste",
                                                title="Part des entreprises par catégorie", color_discrete_sequence=['orange'])

    # Graphique pour la taille moyenne des entreprises par catégorie
    fig_taille_moyenne_entreprises = px.bar(df_filtered, x="Niveau de poste", y="NOMBRE_DE_POSTES_A_POURVOIR",
                                             title="Taille moyenne des entreprises par catégorie", color_discrete_sequence=['orange'])

    return fig_secteur_activite, fig_entreprise, fig_type_contrat, fig_part_entreprises_par_type, fig_part_entreprises_par_categorie, fig_taille_moyenne_entreprises

if __name__ == '__main__':
    app.run_server(debug=True, port=8058)

    # Récupérer les figures après l'exécution de l'application
    fig_secteur_activite, fig_entreprise, fig_type_contrat, fig_part_entreprises_par_type, fig_part_entreprises_par_categorie, fig_taille_moyenne_entreprises = update_graphs(
        None, None, None, None)

    # Sauvegarder les graphiques au format HTML
    write_html(fig_secteur_activite, 'graph_secteur_activite.html')
    write_html(fig_entreprise, 'graph_entreprise.html')
    write_html(fig_type_contrat, 'graph_type_contrat.html')
    write_html(fig_part_entreprises_par_type, 'graph_part_entreprises_par_type.html')
    write_html(fig_part_entreprises_par_categorie, 'graph_part_entreprises_par_categorie.html')
    write_html(fig_taille_moyenne_entreprises, 'graph_taille_moyenne_entreprises.html')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8058/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
